# %% [markdown]
# Initialize Sentiment Analyzer

# %%
import nltk
import warnings
warnings.filterwarnings('ignore')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import time
import pprint
import requests
nltk.download('vader_lexicon')
import datetime
import backtrader as bt

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nishi\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# Updating Vader Lexicon with External Lexicon

# %%
import csv
import pandas as pd

# stock market lexicon
stock_lex = pd.read_csv('lexicon_data/stock_lex.csv')
stock_lex['sentiment'] = (stock_lex['Aff_Score'] + stock_lex['Neg_Score'])/2
stock_lex = dict(zip(stock_lex.Item, stock_lex.sentiment))
stock_lex = {k:v for k,v in stock_lex.items() if len(k.split(' '))==1}
stock_lex_scaled = {}
for k, v in stock_lex.items():
    if v > 0:
        stock_lex_scaled[k] = v / max(stock_lex.values()) * 4
    else:
        stock_lex_scaled[k] = v / min(stock_lex.values()) * -4

# Loughran and McDonald
positive = []
with open('lexicon_data/lm_positive.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        positive.append(row[0].strip())
    
negative = []
with open('lexicon_data/lm_negative.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        entry = row[0].strip().split(" ")
        if len(entry) > 1:
            negative.extend(entry)
        else:
            negative.append(entry[0])

final_lex = {}
final_lex.update({word:2.0 for word in positive})
final_lex.update({word:-2.0 for word in negative})
final_lex.update(stock_lex_scaled)
final_lex.update(sia.lexicon)
sia.lexicon = final_lex

# %%
from dateutil import parser
import time
pages = 2
date_sentiments = {}
search_term = 'john keells'
for i in range(pages):
    url  = f'https://economynext.com/page/{str(i)}/?s={search_term}'
    page = requests.get(url,
                        headers = {'User-Agent': 'Mozilla/5.0'}).text
    soup = BeautifulSoup(page, 'lxml')
    posts = soup.findAll("div", {"class": "story-grid-single-story"})
    for post in posts:
        post_url = post.a['href']
        post_page = requests.get(post_url,
                        headers = {'User-Agent': 'Mozilla/5.0'}).content
        time.wait(0.1)
        story_soup = BeautifulSoup(post_page, 'lxml')
        date_str = story_soup.find('div',class_ = 'story-page-pulish-datetime').text

        #TODO: parse date_str
        story_body = story_soup.find('div',class_ = 'story-page-text-content').text
        date = parser.parse(date_str)
        if date > datetime.datetime(2020,1,1):
            print(date,post_url)



            sentiment = sia.polarity_scores(story_body)['compound']

            date_sentiments.setdefault(date, []).append(sentiment)
# Out:
# 2021-07-29 08:42:00 https://economynext.com/sri-lankas-adani-backed-container-terminal-finalizing-design-structuring-john-keells-84389/
# 2021-07-28 17:47:00 https://economynext.com/sri-lanka-john-keells-holdings-back-in-profits-in-june-2021-quarter-84360/
# 2021-07-19 05:51:00 https://economynext.com/sri-lankas-john-keells-properties-say-tri-zen-project-on-track-84107/
# 2021-07-12 17:58:00 https://economynext.com/brand_voice/john-keells-holdings-the-pursuit-of-inclusive-growth/
# 2021-05-31 07:41:00 https://economynext.com/sri-lankas-john-keells-to-get-34-pct-of-container-terminal-adani-51-pct-report-82559/
# 2021-02-28 08:11:00 https://economynext.com/sri-lanka-golf-holiday-homes-launched-by-john-keells-79211/
# 2021-01-29 05:28:00 https://economynext.com/sri-lankas-john-keells-holdings-net-down-59-pct-in-dec-78336/
# 2020-11-12 12:51:00 https://economynext.com/brand_voice/john-keells-properties-leading-sri-lankas-real-estate-journey/
# 2020-10-11 13:23:00 https://economynext.com/sri-lankas-john-keells-launches-luxury-houses-at-troon-run-golf-resort-74679/
# 2020-08-12 14:59:00 https://economynext.com/brand_voice/john-keells-properties-launches-freedom-mortgages-pioneering-new-home-loan-scheme-with-commercial-bank-waives-interest-for-two-years/
# 2020-07-29 20:21:00 https://economynext.com/john-keells-holdings-loses-rs1-6bn-to-sri-lanka-covid-19-lockdown-sees-recovery-72512/
# 2020-06-23 20:24:00 https://economynext.com/sri-lankas-john-keells-holdings-gets-us175mn-from-ifc-71373/
# 2020-05-21 17:21:00 https://economynext.com/sri-lankas-john-keells-holdings-net-up-18-pct-in-march-70231/
# 2020-02-24 18:45:00 https://economynext.com/sri-lanka-stocks-fall-on-john-keells-holdings-53223/
# 2020-02-11 17:42:00 https://economynext.com/sri-lanka-stocks-fall-on-john-keells-holdings-distilleries-49347/
# 2020-02-10 15:43:00 https://economynext.com/sri-lanka-stocks-end-four-day-rally-on-john-keells-holdings-48905/
# 2020-01-29 17:32:00 https://economynext.com/sri-lankas-john-keells-holding-profits-down-on-hotels-interest-in-december-44545/
# 2020-01-27 16:26:00 https://economynext.com/sri-lanka-stocks-end-0-95-percent-lower-on-john-keells-holdings-42458/
# 2020-01-22 15:06:00 https://economynext.com/sri-lanka-stocks-surge-on-john-keells-holdings-41473/
# 2020-01-14 10:20:00 https://economynext.com/brand_voice/john-keells-properties-is-redefining-the-property-market/
# 2021-07-29 08:42:00 https://economynext.com/sri-lankas-adani-backed-container-terminal-finalizing-design-structuring-john-keells-84389/
# 2021-07-28 17:47:00 https://economynext.com/sri-lanka-john-keells-holdings-back-in-profits-in-june-2021-quarter-84360/
# 2021-07-19 05:51:00 https://economynext.com/sri-lankas-john-keells-properties-say-tri-zen-project-on-track-84107/
# 2021-07-12 17:58:00 https://economynext.com/brand_voice/john-keells-holdings-the-pursuit-of-inclusive-growth/
# 2021-05-31 07:41:00 https://economynext.com/sri-lankas-john-keells-to-get-34-pct-of-container-terminal-adani-51-pct-report-82559/
# 2021-02-28 08:11:00 https://economynext.com/sri-lanka-golf-holiday-homes-launched-by-john-keells-79211/
# 2021-01-29 05:28:00 https://economynext.com/sri-lankas-john-keells-holdings-net-down-59-pct-in-dec-78336/
# 2020-11-12 12:51:00 https://economynext.com/brand_voice/john-keells-properties-leading-sri-lankas-real-estate-journey/
# 2020-10-11 13:23:00 https://economynext.com/sri-lankas-john-keells-launches-luxury-houses-at-troon-run-golf-resort-74679/
# 2020-08-12 14:59:00 https://economynext.com/brand_voice/john-keells-properties-launches-freedom-mortgages-pioneering-new-home-loan-scheme-with-commercial-bank-waives-interest-for-two-years/
# 2020-07-29 20:21:00 https://economynext.com/john-keells-holdings-loses-rs1-6bn-to-sri-lanka-covid-19-lockdown-sees-recovery-72512/
# 2020-06-23 20:24:00 https://economynext.com/sri-lankas-john-keells-holdings-gets-us175mn-from-ifc-71373/
# 2020-05-21 17:21:00 https://economynext.com/sri-lankas-john-keells-holdings-net-up-18-pct-in-march-70231/
# 2020-02-24 18:45:00 https://economynext.com/sri-lanka-stocks-fall-on-john-keells-holdings-53223/
# 2020-02-11 17:42:00 https://economynext.com/sri-lanka-stocks-fall-on-john-keells-holdings-distilleries-49347/
# 2020-02-10 15:43:00 https://economynext.com/sri-lanka-stocks-end-four-day-rally-on-john-keells-holdings-48905/
# 2020-01-29 17:32:00 https://economynext.com/sri-lankas-john-keells-holding-profits-down-on-hotels-interest-in-december-44545/
# 2020-01-27 16:26:00 https://economynext.com/sri-lanka-stocks-end-0-95-percent-lower-on-john-keells-holdings-42458/
# 2020-01-22 15:06:00 https://economynext.com/sri-lanka-stocks-surge-on-john-keells-holdings-41473/
# 2020-01-14 10:20:00 https://economynext.com/brand_voice/john-keells-properties-is-redefining-the-property-market/

# %%
date_sentiment = {}
for k,v in date_sentiments.items():
    #why this time delta, consider param?
    date_sentiment[k.date() + timedelta(days=1)] = round(sum(v)/float(len(v)),3) #avg sentiment for a day

earliest_date = min(date_sentiment.keys())
earliest_datetime = datetime.datetime(earliest_date.year, earliest_date.month, earliest_date.day)
print(date_sentiment)
print(earliest_date)
# Out:
# {datetime.date(2021, 7, 30): 0.766, datetime.date(2021, 7, 29): 0.99, datetime.date(2021, 7, 20): 0.907, datetime.date(2021, 7, 13): 1.0, datetime.date(2021, 6, 1): 0.979, datetime.date(2021, 3, 1): 0.988, datetime.date(2021, 1, 30): 0.999, datetime.date(2020, 11, 13): 1.0, datetime.date(2020, 10, 12): 0.991, datetime.date(2020, 8, 13): 0.999, datetime.date(2020, 7, 30): 0.989, datetime.date(2020, 6, 24): 0.996, datetime.date(2020, 5, 22): 0.994, datetime.date(2020, 2, 25): 0.926, datetime.date(2020, 2, 12): 0.464, datetime.date(2020, 2, 11): 0.633, datetime.date(2020, 1, 30): 0.976, datetime.date(2020, 1, 28): -0.069, datetime.date(2020, 1, 23): 0.99, datetime.date(2020, 1, 15): 1.0}
# 2020-01-15

# %%
# for i in df.volume:
def _to_float(x):
    
    if 'M' in x:
         out = float(x[:-1])*10**6
            
    elif 'K' in x:
        out = float(x[:-1])*10**3
    else:
        out = float(x)
    
    return out


def get_datafeed(filepath, earliest_date,reverse=False):
    "Builds feed from custom csv"
    df = pd.read_csv(filepath,parse_dates = True)
    
    df['datetime'] = pd.to_datetime(df['datetime'])
    
    df.volume = df['volume'].apply(lambda x: _to_float(x))
    
    df = df[df.datetime > earliest_datetime ]
    if reverse:
        df = df[::-1]
    data = bt.feeds.PandasData(dataname=df,
                              datetime = -1
                            )
    
    return data



def test_get_datafeed():
    """This plot should show we loaded the data succesfully"""
    # Create a cerebro entity
    cerebro = bt.Cerebro(stdstats=False)

    # Add a strategy
    cerebro.addstrategy(bt.Strategy)

    cerebro.adddata(get_datafeed('data/SAMP Historical Data.csv',earliest_date))

    # Run over everything
    cerebro.run()

    # Plot the result
    cerebro.plot(style='bar')

test_get_datafeed()
# Out:
# <img src="data:image/png;base64,..." width="431.66664951377516">

# %%
df = pd.read_csv('data/SAMP Historical Data.csv')
df['datetime'] = pd.to_datetime(df['datetime'])
df.volume = df['volume'].apply(lambda x: to_float(x))
# df.volume = pd.to_numeric(df.volume)
df.info()
df.isna().sum()
import matplotlib.pyplot as plt
plt.plot(df.datetime,df.close)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466 entries, 0 to 465
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    466 non-null    datetime64[ns]
#  1   close       466 non-null    float64
#  2   open        466 non-null    float64
#  3   high        466 non-null    float64
#  4   low         466 non-null    float64
#  5   volume      466 non-null    float64
#  6   Unnamed: 6  0 non-null      float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 25.6 KB
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# Scraping FB posts from Business Times

# %%
# from urllib.request import urlopen
# from bs4 import BeautifulSoup
# from datetime import datetime, timedelta
# import time
# import pprint
# import requests
# date_sentiments = {}

# for i in range(1,3):
#     page = requests.get('https://www.businesstimes.com.sg/search/facebook?page='+str(i)).text
#     soup = BeautifulSoup(page, 'lxml')
#     posts = soup.findAll("div", {"class": "media-body"})

#     for post in posts:
#         time.sleep(1)
#         url = post.a['href']
#         date = post.time.text
#         print(date)
#         print(date, url)
#         try:
#             link_page = urlopen(url).read()
#         except:
#             url = url[:-2]
#             link_page = urlopen(url).read()
#         link_soup = BeautifulSoup(link_page)
#         sentences = link_soup.findAll("p")
#         passage = ""
#         for sentence in sentences:
#             passage += sentence.text
        
#         sentiment = sia.polarity_scores(passage)['compound']
#         date_sentiments.setdefault(date, []).append(sentiment)



# for k,v in date_sentiments.items():
#     date_sentiment[datetime.strptime(k, '%d %b %Y').date() + timedelta(days=1)] = round(sum(v)/float(len(v)),3)

# earliest_date = min(date_sentiment.keys())

# print(date_sentiment)

# %% [markdown]
# Algorithm

# %%
from __future__ import (absolute_import, division, print_function,
                            unicode_literals)

# %matplotlib inline
# import warnings
# warnings.filterwarnings('ignore')
import yfinance as yf
import backtrader as bt
import backtrader.indicators as btind
import datetime
import os.path
# import sys

class Sentiment(bt.Indicator):
    lines = ('sentiment',)
    plotinfo = dict(
        plotymargin=0.15,
        plothlines=[0],
        plotyticks=[1.0, 0, -1.0])

        
    def next(self):
        self.date = self.data.datetime
        date = bt.num2date(self.date[0]).date()
        prev_sentiment = self.sentiment
        if date in date_sentiment:
            self.sentiment = date_sentiment[date]
        try:
            self.lines.sentiment[0] = self.sentiment
        except:
            self.lines.sentiment[0] = 0
            


class SentimentStrat(bt.Strategy):
    params = (
        ('period', 8),
        ('printlog', True),
    )

    def log(self, txt, dt=None, doprint=False):
        ''' Logging function for this strategy'''
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # Keep a reference to the "close" line in the data[0] dataseries
        self.dataclose = self.datas[0].close
        # Keep track of pending orders
        self.order = None
        self.buyprice = None
        self.buycomm = None
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.period)
        self.date = self.data.datetime
        self.sentiment = None
        Sentiment(self.data)
        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return
        
        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))
                
            self.bar_executed = len(self)     
            
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')
            
        # Write down: no pending order
        self.order = None
        
    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))
    
    ### Main Strat ###
    def next(self):
        # log closing price of the series from the reference
        self.log('Close, %.2f' % self.dataclose[0])
        
#         date = bt.num2date(self.date[0]).date()
        date  = self.datetime.date()
        prev_sentiment = self.sentiment
        if date in date_sentiment:
            self.sentiment = date_sentiment[date]
        
        # Check if an order is pending. if yes, we cannot send a 2nd one
        if self.order:
            return
        print(self.sentiment,prev_sentiment)
        # If not in the market and previous sentiment not none
        if not self.position and prev_sentiment:
#         if prev_sentiment:
            # buy if current close more than sma AND sentiment increased by >= 0.5
#             if self.dataclose[0] > self.sma[0] and self.sentiment - prev_sentiment >= 0.01:
            if self.sentiment - prev_sentiment <= +0.01:
                self.log('BUY CREATE, %.2f' % self.dataclose[0])
                self.order = self.buy()
                
        # Already in the market and previous sentiment not none
        elif prev_sentiment:
            # sell if current close less than sma AND sentiment decreased by >= 0.5
#             if self.dataclose[0] < self.sma[0] or self.sentiment - prev_sentiment <= -0.01:
#             if self.sentiment - prev_sentiment <= -0.01:
                self.log('SELL CREATE, %.2f' % self.dataclose[0])
                self.order = self.sell()

    def stop(self):
        self.log('(MA Period %2d) Ending Value %.2f' %
                 (self.params.period, self.broker.getvalue()), doprint=True)
        


if __name__ == '__main__':
    cerebro = bt.Cerebro()
    
    # Strategy
    cerebro.addstrategy(SentimentStrat)

    # Data Feed
    data = get_datafeed('data/SAMP Historical Data.csv',earliest_date,reverse=True)

    cerebro.adddata(data)

    cerebro.broker.setcash(100000.0)
    cerebro.addsizer(bt.sizers.FixedSize, stake=10)
    cerebro.broker.setcommission(commission=0.001)
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
    cerebro.run()
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    cerebro.plot()
# Out:
# Starting Portfolio Value: 100000.00
# 2020-01-27, Close, 54.00
# None None
# 2020-01-28, Close, 53.67
# -0.069 None
# 2020-01-29, Close, 54.83
# -0.069 -0.069
# 2020-01-29, BUY CREATE, 54.83
# 2020-01-30, BUY EXECUTED, Price: 54.67, Cost: 546.70, Comm 0.55
# 2020-01-30, Close, 54.67
# 0.976 -0.069
# 2020-01-30, SELL CREATE, 54.67
# 2020-01-31, SELL EXECUTED, Price: 54.67, Cost: 546.70, Comm 0.55
# 2020-01-31, OPERATION PROFIT, GROSS 0.00, NET -1.09
# 2020-01-31, Close, 54.33
# 0.976 0.976
# 2020-01-31, BUY CREATE, 54.33
# 2020-02-03, BUY EXECUTED, Price: 54.63, Cost: 546.30, Comm 0.55
# 2020-02-03, Close, 54.40
# 0.976 0.976
# 2020-02-03, SELL CREATE, 54.40
# 2020-02-05, SELL EXECUTED, Price: 54.63, Cost: 546.30, Comm 0.55
# 2020-02-05, OPERATION PROFIT, GROSS -0.00, NET -1.09
# 2020-02-05, Close, 54.63
# 0.976 0.976
# 2020-02-05, BUY CREATE, 54.63
# 2020-02-06, BUY EXECUTED, Price: 54.37, Cost: 543.70, Comm 0.54
# 2020-02-06, Close, 54.33
# 0.976 0.976
# 2020-02-06, SELL CREATE, 54.33
# 2020-02-07, SELL EXECUTED, Price: 54.33, Cost: 543.70, Comm 0.54
# 2020-02-07, OPERATION PROFIT, GROSS -0.40, NET -1.49
# 2020-02-07, Close, 54.00
# 0.976 0.976
# 2020-02-07, BUY CREATE, 54.00
# 2020-02-10, BUY EXECUTED, Price: 53.83, Cost: 538.30, Comm 0.54
# 2020-02-10, Close, 53.97
# 0.976 0.976
# 2020-02-10, SELL CREATE, 53.97
# 2020-02-11, SELL EXECUTED, Price: 53.83, Cost: 538.30, Comm 0.54
# 2020-02-11, OPERATION PROFIT, GROSS 0.00, NET -1.08
# 2020-02-11, Close, 53.33
# 0.633 0.976
# 2020-02-11, BUY CREATE, 53.33
# 2020-02-12, BUY EXECUTED, Price: 53.33, Cost: 533.30, Comm 0.53
# 2020-02-12, Close, 53.97
# 0.464 0.633
# 2020-02-12, SELL CREATE, 53.97
# 2020-02-13, SELL EXECUTED, Price: 53.33, Cost: 533.30, Comm 0.53
# 2020-02-13, OPERATION PROFIT, GROSS 0.00, NET -1.07
# 2020-02-13, Close, 53.97
# 0.464 0.464
# 2020-02-13, BUY CREATE, 53.97
# 2020-02-14, BUY EXECUTED, Price: 54.50, Cost: 545.00, Comm 0.55
# 2020-02-14, Close, 55.67
# 0.464 0.464
# 2020-02-14, SELL CREATE, 55.67
# 2020-02-17, SELL EXECUTED, Price: 55.67, Cost: 545.00, Comm 0.56
# 2020-02-17, OPERATION PROFIT, GROSS 11.70, NET 10.60
# 2020-02-17, Close, 55.33
# 0.464 0.464
# 2020-02-17, BUY CREATE, 55.33
# 2020-02-18, BUY EXECUTED, Price: 55.50, Cost: 555.00, Comm 0.56
# 2020-02-18, Close, 55.67
# 0.464 0.464
# 2020-02-18, SELL CREATE, 55.67
# 2020-02-19, SELL EXECUTED, Price: 55.67, Cost: 555.00, Comm 0.56
# 2020-02-19, OPERATION PROFIT, GROSS 1.70, NET 0.59
# 2020-02-19, Close, 55.83
# 0.464 0.464
# 2020-02-19, BUY CREATE, 55.83
# 2020-02-20, BUY EXECUTED, Price: 55.83, Cost: 558.30, Comm 0.56
# 2020-02-20, Close, 55.33
# 0.464 0.464
# 2020-02-20, SELL CREATE, 55.33
# 2020-02-24, SELL EXECUTED, Price: 55.37, Cost: 558.30, Comm 0.55
# 2020-02-24, OPERATION PROFIT, GROSS -4.60, NET -5.71
# 2020-02-24, Close, 55.17
# 0.464 0.464
# 2020-02-24, BUY CREATE, 55.17
# 2020-02-25, BUY EXECUTED, Price: 55.33, Cost: 553.30, Comm 0.55
# 2020-02-25, Close, 54.33
# 0.926 0.464
# 2020-02-25, SELL CREATE, 54.33
# 2020-02-26, SELL EXECUTED, Price: 54.50, Cost: 553.30, Comm 0.55
# 2020-02-26, OPERATION PROFIT, GROSS -8.30, NET -9.40
# 2020-02-26, Close, 53.33
# 0.926 0.926
# 2020-02-26, BUY CREATE, 53.33
# 2020-02-27, BUY EXECUTED, Price: 53.33, Cost: 533.30, Comm 0.53
# 2020-02-27, Close, 53.67
# 0.926 0.926
# 2020-02-27, SELL CREATE, 53.67
# 2020-02-28, SELL EXECUTED, Price: 53.33, Cost: 533.30, Comm 0.53
# 2020-02-28, OPERATION PROFIT, GROSS 0.00, NET -1.07
# 2020-02-28, Close, 53.27
# 0.926 0.926
# 2020-02-28, BUY CREATE, 53.27
# 2020-03-02, BUY EXECUTED, Price: 53.17, Cost: 531.70, Comm 0.53
# 2020-03-02, Close, 52.67
# 0.926 0.926
# 2020-03-02, SELL CREATE, 52.67
# 2020-03-03, SELL EXECUTED, Price: 52.83, Cost: 531.70, Comm 0.53
# 2020-03-03, OPERATION PROFIT, GROSS -3.40, NET -4.46
# 2020-03-03, Close, 53.00
# 0.926 0.926
# 2020-03-03, BUY CREATE, 53.00
# 2020-03-04, BUY EXECUTED, Price: 53.00, Cost: 530.00, Comm 0.53
# 2020-03-04, Close, 51.67
# 0.926 0.926
# 2020-03-04, SELL CREATE, 51.67
# 2020-03-05, SELL EXECUTED, Price: 51.67, Cost: 530.00, Comm 0.52
# 2020-03-05, OPERATION PROFIT, GROSS -13.30, NET -14.35
# 2020-03-05, Close, 51.17
# 0.926 0.926
# 2020-03-05, BUY CREATE, 51.17
# 2020-03-06, BUY EXECUTED, Price: 51.07, Cost: 510.70, Comm 0.51
# 2020-03-06, Close, 50.83
# 0.926 0.926
# 2020-03-06, SELL CREATE, 50.83
# 2020-03-10, SELL EXECUTED, Price: 50.00, Cost: 510.70, Comm 0.50
# 2020-03-10, OPERATION PROFIT, GROSS -10.70, NET -11.71
# 2020-03-10, Close, 48.53
# 0.926 0.926
# 2020-03-10, BUY CREATE, 48.53
# 2020-03-11, BUY EXECUTED, Price: 48.37, Cost: 483.70, Comm 0.48
# 2020-03-11, Close, 49.00
# 0.926 0.926
# 2020-03-11, SELL CREATE, 49.00
# 2020-03-12, SELL EXECUTED, Price: 48.67, Cost: 483.70, Comm 0.49
# 2020-03-12, OPERATION PROFIT, GROSS 3.00, NET 2.03
# 2020-03-12, Close, 46.67
# 0.926 0.926
# 2020-03-12, BUY CREATE, 46.67
# 2020-03-13, BUY EXECUTED, Price: 46.40, Cost: 464.00, Comm 0.46
# 2020-03-13, Close, 45.70
# 0.926 0.926
# 2020-03-13, SELL CREATE, 45.70
# 2020-03-20, SELL EXECUTED, Price: 43.33, Cost: 464.00, Comm 0.43
# 2020-03-20, OPERATION PROFIT, GROSS -30.70, NET -31.60
# 2020-03-20, Close, 39.67
# 0.926 0.926
# 2020-03-20, BUY CREATE, 39.67
# 2020-05-11, BUY EXECUTED, Price: 33.33, Cost: 333.30, Comm 0.33
# 2020-05-11, Close, 33.33
# 0.926 0.926
# 2020-05-11, SELL CREATE, 33.33
# 2020-05-12, SELL EXECUTED, Price: 32.33, Cost: 333.30, Comm 0.32
# 2020-05-12, OPERATION PROFIT, GROSS -10.00, NET -10.66
# 2020-05-12, Close, 33.00
# 0.926 0.926
# 2020-05-12, BUY CREATE, 33.00
# 2020-05-13, BUY EXECUTED, Price: 35.30, Cost: 353.00, Comm 0.35
# 2020-05-13, Close, 34.33
# 0.926 0.926
# 2020-05-13, SELL CREATE, 34.33
# 2020-05-14, SELL EXECUTED, Price: 33.33, Cost: 353.00, Comm 0.33
# 2020-05-14, OPERATION PROFIT, GROSS -19.70, NET -20.39
# 2020-05-14, Close, 35.00
# 0.926 0.926
# 2020-05-14, BUY CREATE, 35.00
# 2020-05-15, BUY EXECUTED, Price: 35.33, Cost: 353.30, Comm 0.35
# 2020-05-15, Close, 36.53
# 0.926 0.926
# 2020-05-15, SELL CREATE, 36.53
# 2020-05-18, SELL EXECUTED, Price: 37.67, Cost: 353.30, Comm 0.38
# 2020-05-18, OPERATION PROFIT, GROSS 23.40, NET 22.67
# 2020-05-18, Close, 38.20
# 0.926 0.926
# 2020-05-18, BUY CREATE, 38.20
# 2020-05-19, BUY EXECUTED, Price: 39.00, Cost: 390.00, Comm 0.39
# 2020-05-19, Close, 38.33
# 0.926 0.926
# 2020-05-19, SELL CREATE, 38.33
# 2020-05-20, SELL EXECUTED, Price: 38.67, Cost: 390.00, Comm 0.39
# 2020-05-20, OPERATION PROFIT, GROSS -3.30, NET -4.08
# 2020-05-20, Close, 39.67
# 0.926 0.926
# 2020-05-20, BUY CREATE, 39.67
# 2020-05-21, BUY EXECUTED, Price: 39.93, Cost: 399.30, Comm 0.40
# 2020-05-21, Close, 41.17
# 0.926 0.926
# 2020-05-21, SELL CREATE, 41.17
# 2020-05-22, SELL EXECUTED, Price: 41.63, Cost: 399.30, Comm 0.42
# 2020-05-22, OPERATION PROFIT, GROSS 17.00, NET 16.18
# 2020-05-22, Close, 40.53
# 0.994 0.926
# 2020-05-26, Close, 39.33
# 0.994 0.994
# 2020-05-26, BUY CREATE, 39.33
# 2020-05-27, BUY EXECUTED, Price: 39.33, Cost: 393.30, Comm 0.39
# 2020-05-27, Close, 39.23
# 0.994 0.994
# 2020-05-27, SELL CREATE, 39.23
# 2020-05-28, SELL EXECUTED, Price: 40.00, Cost: 393.30, Comm 0.40
# 2020-05-28, OPERATION PROFIT, GROSS 6.70, NET 5.91
# 2020-05-28, Close, 40.00
# 0.994 0.994
# 2020-05-28, BUY CREATE, 40.00
# 2020-05-29, BUY EXECUTED, Price: 41.00, Cost: 410.00, Comm 0.41
# 2020-05-29, Close, 39.67
# 0.994 0.994
# 2020-05-29, SELL CREATE, 39.67
# 2020-06-01, SELL EXECUTED, Price: 39.53, Cost: 410.00, Comm 0.40
# 2020-06-01, OPERATION PROFIT, GROSS -14.70, NET -15.51
# 2020-06-01, Close, 38.00
# 0.994 0.994
# 2020-06-01, BUY CREATE, 38.00
# 2020-06-02, BUY EXECUTED, Price: 38.33, Cost: 383.30, Comm 0.38
# 2020-06-02, Close, 38.73
# 0.994 0.994
# 2020-06-02, SELL CREATE, 38.73
# 2020-06-03, SELL EXECUTED, Price: 35.00, Cost: 383.30, Comm 0.35
# 2020-06-03, OPERATION PROFIT, GROSS -33.30, NET -34.03
# 2020-06-03, Close, 35.27
# 0.994 0.994
# 2020-06-03, BUY CREATE, 35.27
# 2020-06-04, BUY EXECUTED, Price: 35.33, Cost: 353.30, Comm 0.35
# 2020-06-04, Close, 35.00
# 0.994 0.994
# 2020-06-04, SELL CREATE, 35.00
# 2020-06-08, SELL EXECUTED, Price: 35.50, Cost: 353.30, Comm 0.35
# 2020-06-08, OPERATION PROFIT, GROSS 1.70, NET 0.99
# 2020-06-08, Close, 35.57
# 0.994 0.994
# 2020-06-08, BUY CREATE, 35.57
# 2020-06-09, BUY EXECUTED, Price: 35.67, Cost: 356.70, Comm 0.36
# 2020-06-09, Close, 36.00
# 0.994 0.994
# 2020-06-09, SELL CREATE, 36.00
# 2020-06-10, SELL EXECUTED, Price: 36.00, Cost: 356.70, Comm 0.36
# 2020-06-10, OPERATION PROFIT, GROSS 3.30, NET 2.58
# 2020-06-10, Close, 36.13
# 0.994 0.994
# 2020-06-10, BUY CREATE, 36.13
# 2020-06-11, BUY EXECUTED, Price: 36.00, Cost: 360.00, Comm 0.36
# 2020-06-11, Close, 36.40
# 0.994 0.994
# 2020-06-11, SELL CREATE, 36.40
# 2020-06-12, SELL EXECUTED, Price: 36.33, Cost: 360.00, Comm 0.36
# 2020-06-12, OPERATION PROFIT, GROSS 3.30, NET 2.58
# 2020-06-12, Close, 36.67
# 0.994 0.994
# 2020-06-12, BUY CREATE, 36.67
# 2020-06-15, BUY EXECUTED, Price: 36.33, Cost: 363.30, Comm 0.36
# 2020-06-15, Close, 37.00
# 0.994 0.994
# 2020-06-15, SELL CREATE, 37.00
# 2020-06-16, SELL EXECUTED, Price: 37.00, Cost: 363.30, Comm 0.37
# 2020-06-16, OPERATION PROFIT, GROSS 6.70, NET 5.97
# 2020-06-16, Close, 38.00
# 0.994 0.994
# 2020-06-16, BUY CREATE, 38.00
# 2020-06-17, BUY EXECUTED, Price: 38.37, Cost: 383.70, Comm 0.38
# 2020-06-17, Close, 39.17
# 0.994 0.994
# 2020-06-17, SELL CREATE, 39.17
# 2020-06-18, SELL EXECUTED, Price: 39.33, Cost: 383.70, Comm 0.39
# 2020-06-18, OPERATION PROFIT, GROSS 9.60, NET 8.82
# 2020-06-18, Close, 39.67
# 0.994 0.994
# 2020-06-18, BUY CREATE, 39.67
# 2020-06-19, BUY EXECUTED, Price: 39.67, Cost: 396.70, Comm 0.40
# 2020-06-19, Close, 39.90
# 0.994 0.994
# 2020-06-19, SELL CREATE, 39.90
# 2020-06-22, SELL EXECUTED, Price: 39.97, Cost: 396.70, Comm 0.40
# 2020-06-22, OPERATION PROFIT, GROSS 3.00, NET 2.20
# 2020-06-22, Close, 41.67
# 0.994 0.994
# 2020-06-22, BUY CREATE, 41.67
# 2020-06-23, BUY EXECUTED, Price: 42.00, Cost: 420.00, Comm 0.42
# 2020-06-23, Close, 42.80
# 0.994 0.994
# 2020-06-23, SELL CREATE, 42.80
# 2020-06-24, SELL EXECUTED, Price: 43.13, Cost: 420.00, Comm 0.43
# 2020-06-24, OPERATION PROFIT, GROSS 11.30, NET 10.45
# 2020-06-24, Close, 42.63
# 0.996 0.994
# 2020-06-24, BUY CREATE, 42.63
# 2020-06-25, BUY EXECUTED, Price: 43.00, Cost: 430.00, Comm 0.43
# 2020-06-25, Close, 42.17
# 0.996 0.996
# 2020-06-25, SELL CREATE, 42.17
# 2020-06-26, SELL EXECUTED, Price: 42.17, Cost: 430.00, Comm 0.42
# 2020-06-26, OPERATION PROFIT, GROSS -8.30, NET -9.15
# 2020-06-26, Close, 42.27
# 0.996 0.996
# 2020-06-26, BUY CREATE, 42.27
# 2020-06-29, BUY EXECUTED, Price: 42.00, Cost: 420.00, Comm 0.42
# 2020-06-29, Close, 42.13
# 0.996 0.996
# 2020-06-29, SELL CREATE, 42.13
# 2020-06-30, SELL EXECUTED, Price: 42.10, Cost: 420.00, Comm 0.42
# 2020-06-30, OPERATION PROFIT, GROSS 1.00, NET 0.16
# 2020-06-30, Close, 42.17
# 0.996 0.996
# 2020-06-30, BUY CREATE, 42.17
# 2020-07-01, BUY EXECUTED, Price: 42.17, Cost: 421.70, Comm 0.42
# 2020-07-01, Close, 42.17
# 0.996 0.996
# 2020-07-01, SELL CREATE, 42.17
# 2020-07-02, SELL EXECUTED, Price: 42.00, Cost: 421.70, Comm 0.42
# 2020-07-02, OPERATION PROFIT, GROSS -1.70, NET -2.54
# 2020-07-02, Close, 41.83
# 0.996 0.996
# 2020-07-02, BUY CREATE, 41.83
# 2020-07-03, BUY EXECUTED, Price: 41.17, Cost: 411.70, Comm 0.41
# 2020-07-03, Close, 40.77
# 0.996 0.996
# 2020-07-03, SELL CREATE, 40.77
# 2020-07-06, SELL EXECUTED, Price: 40.67, Cost: 411.70, Comm 0.41
# 2020-07-06, OPERATION PROFIT, GROSS -5.00, NET -5.82
# 2020-07-06, Close, 40.33
# 0.996 0.996
# 2020-07-06, BUY CREATE, 40.33
# 2020-07-07, BUY EXECUTED, Price: 40.33, Cost: 403.30, Comm 0.40
# 2020-07-07, Close, 41.63
# 0.996 0.996
# 2020-07-07, SELL CREATE, 41.63
# 2020-07-08, SELL EXECUTED, Price: 41.67, Cost: 403.30, Comm 0.42
# 2020-07-08, OPERATION PROFIT, GROSS 13.40, NET 12.58
# 2020-07-08, Close, 40.90
# 0.996 0.996
# 2020-07-08, BUY CREATE, 40.90
# 2020-07-09, BUY EXECUTED, Price: 41.33, Cost: 413.30, Comm 0.41
# 2020-07-09, Close, 41.67
# 0.996 0.996
# 2020-07-09, SELL CREATE, 41.67
# 2020-07-10, SELL EXECUTED, Price: 40.67, Cost: 413.30, Comm 0.41
# 2020-07-10, OPERATION PROFIT, GROSS -6.60, NET -7.42
# 2020-07-10, Close, 40.27
# 0.996 0.996
# 2020-07-10, BUY CREATE, 40.27
# 2020-07-13, BUY EXECUTED, Price: 39.33, Cost: 393.30, Comm 0.39
# 2020-07-13, Close, 38.67
# 0.996 0.996
# 2020-07-13, SELL CREATE, 38.67
# 2020-07-14, SELL EXECUTED, Price: 38.67, Cost: 393.30, Comm 0.39
# 2020-07-14, OPERATION PROFIT, GROSS -6.60, NET -7.38
# 2020-07-14, Close, 39.33
# 0.996 0.996
# 2020-07-14, BUY CREATE, 39.33
# 2020-07-15, BUY EXECUTED, Price: 39.67, Cost: 396.70, Comm 0.40
# 2020-07-15, Close, 39.43
# 0.996 0.996
# 2020-07-15, SELL CREATE, 39.43
# 2020-07-16, SELL EXECUTED, Price: 39.63, Cost: 396.70, Comm 0.40
# 2020-07-16, OPERATION PROFIT, GROSS -0.40, NET -1.19
# 2020-07-16, Close, 40.17
# 0.996 0.996
# 2020-07-16, BUY CREATE, 40.17
# 2020-07-17, BUY EXECUTED, Price: 40.33, Cost: 403.30, Comm 0.40
# 2020-07-17, Close, 40.50
# 0.996 0.996
# 2020-07-17, SELL CREATE, 40.50
# 2020-07-20, SELL EXECUTED, Price: 40.67, Cost: 403.30, Comm 0.41
# 2020-07-20, OPERATION PROFIT, GROSS 3.40, NET 2.59
# 2020-07-20, Close, 40.33
# 0.996 0.996
# 2020-07-20, BUY CREATE, 40.33
# 2020-07-21, BUY EXECUTED, Price: 41.00, Cost: 410.00, Comm 0.41
# 2020-07-21, Close, 40.00
# 0.996 0.996
# 2020-07-21, SELL CREATE, 40.00
# 2020-07-22, SELL EXECUTED, Price: 40.00, Cost: 410.00, Comm 0.40
# 2020-07-22, OPERATION PROFIT, GROSS -10.00, NET -10.81
# 2020-07-22, Close, 39.70
# 0.996 0.996
# 2020-07-22, BUY CREATE, 39.70
# 2020-07-23, BUY EXECUTED, Price: 39.67, Cost: 396.70, Comm 0.40
# 2020-07-23, Close, 39.67
# 0.996 0.996
# 2020-07-23, SELL CREATE, 39.67
# 2020-07-24, SELL EXECUTED, Price: 39.63, Cost: 396.70, Comm 0.40
# 2020-07-24, OPERATION PROFIT, GROSS -0.40, NET -1.19
# 2020-07-24, Close, 39.67
# 0.996 0.996
# 2020-07-24, BUY CREATE, 39.67
# 2020-07-27, BUY EXECUTED, Price: 40.00, Cost: 400.00, Comm 0.40
# 2020-07-27, Close, 40.67
# 0.996 0.996
# 2020-07-27, SELL CREATE, 40.67
# 2020-07-28, SELL EXECUTED, Price: 40.67, Cost: 400.00, Comm 0.41
# 2020-07-28, OPERATION PROFIT, GROSS 6.70, NET 5.89
# 2020-07-28, Close, 40.83
# 0.996 0.996
# 2020-07-28, BUY CREATE, 40.83
# 2020-07-29, BUY EXECUTED, Price: 41.00, Cost: 410.00, Comm 0.41
# 2020-07-29, Close, 40.50
# 0.996 0.996
# 2020-07-29, SELL CREATE, 40.50
# 2020-07-30, SELL EXECUTED, Price: 40.60, Cost: 410.00, Comm 0.41
# 2020-07-30, OPERATION PROFIT, GROSS -4.00, NET -4.82
# 2020-07-30, Close, 40.47
# 0.989 0.996
# 2020-07-30, BUY CREATE, 40.47
# 2020-07-31, BUY EXECUTED, Price: 40.50, Cost: 405.00, Comm 0.41
# 2020-07-31, Close, 40.67
# 0.989 0.989
# 2020-07-31, SELL CREATE, 40.67
# 2020-08-04, SELL EXECUTED, Price: 40.70, Cost: 405.00, Comm 0.41
# 2020-08-04, OPERATION PROFIT, GROSS 2.00, NET 1.19
# 2020-08-04, Close, 41.33
# 0.989 0.989
# 2020-08-04, BUY CREATE, 41.33
# 2020-08-05, BUY EXECUTED, Price: 41.33, Cost: 413.30, Comm 0.41
# 2020-08-05, Close, 41.33
# 0.989 0.989
# 2020-08-05, SELL CREATE, 41.33
# 2020-08-06, SELL EXECUTED, Price: 41.67, Cost: 413.30, Comm 0.42
# 2020-08-06, OPERATION PROFIT, GROSS 3.40, NET 2.57
# 2020-08-06, Close, 41.67
# 0.989 0.989
# 2020-08-06, BUY CREATE, 41.67
# 2020-08-07, BUY EXECUTED, Price: 41.67, Cost: 416.70, Comm 0.42
# 2020-08-07, Close, 41.53
# 0.989 0.989
# 2020-08-07, SELL CREATE, 41.53
# 2020-08-10, SELL EXECUTED, Price: 41.63, Cost: 416.70, Comm 0.42
# 2020-08-10, OPERATION PROFIT, GROSS -0.40, NET -1.23
# 2020-08-10, Close, 41.17
# 0.989 0.989
# 2020-08-10, BUY CREATE, 41.17
# 2020-08-11, BUY EXECUTED, Price: 41.07, Cost: 410.70, Comm 0.41
# 2020-08-11, Close, 41.60
# 0.989 0.989
# 2020-08-11, SELL CREATE, 41.60
# 2020-08-12, SELL EXECUTED, Price: 41.67, Cost: 410.70, Comm 0.42
# 2020-08-12, OPERATION PROFIT, GROSS 6.00, NET 5.17
# 2020-08-12, Close, 42.47
# 0.989 0.989
# 2020-08-12, BUY CREATE, 42.47
# 2020-08-13, BUY EXECUTED, Price: 42.53, Cost: 425.30, Comm 0.43
# 2020-08-13, Close, 43.03
# 0.999 0.989
# 2020-08-13, SELL CREATE, 43.03
# 2020-08-14, SELL EXECUTED, Price: 43.00, Cost: 425.30, Comm 0.43
# 2020-08-14, OPERATION PROFIT, GROSS 4.70, NET 3.84
# 2020-08-14, Close, 42.90
# 0.999 0.999
# 2020-08-14, BUY CREATE, 42.90
# 2020-08-17, BUY EXECUTED, Price: 43.00, Cost: 430.00, Comm 0.43
# 2020-08-17, Close, 42.87
# 0.999 0.999
# 2020-08-17, SELL CREATE, 42.87
# 2020-08-18, SELL EXECUTED, Price: 42.83, Cost: 430.00, Comm 0.43
# 2020-08-18, OPERATION PROFIT, GROSS -1.70, NET -2.56
# 2020-08-18, Close, 42.67
# 0.999 0.999
# 2020-08-18, BUY CREATE, 42.67
# 2020-08-19, BUY EXECUTED, Price: 42.67, Cost: 426.70, Comm 0.43
# 2020-08-19, Close, 42.57
# 0.999 0.999
# 2020-08-19, SELL CREATE, 42.57
# 2020-08-20, SELL EXECUTED, Price: 42.67, Cost: 426.70, Comm 0.43
# 2020-08-20, OPERATION PROFIT, GROSS 0.00, NET -0.85
# 2020-08-20, Close, 42.30
# 0.999 0.999
# 2020-08-20, BUY CREATE, 42.30
# 2020-08-21, BUY EXECUTED, Price: 42.67, Cost: 426.70, Comm 0.43
# 2020-08-21, Close, 42.30
# 0.999 0.999
# 2020-08-21, SELL CREATE, 42.30
# 2020-08-24, SELL EXECUTED, Price: 42.67, Cost: 426.70, Comm 0.43
# 2020-08-24, OPERATION PROFIT, GROSS 0.00, NET -0.85
# 2020-08-24, Close, 42.27
# 0.999 0.999
# 2020-08-24, BUY CREATE, 42.27
# 2020-08-25, BUY EXECUTED, Price: 42.33, Cost: 423.30, Comm 0.42
# 2020-08-25, Close, 42.00
# 0.999 0.999
# 2020-08-25, SELL CREATE, 42.00
# 2020-08-26, SELL EXECUTED, Price: 42.00, Cost: 423.30, Comm 0.42
# 2020-08-26, OPERATION PROFIT, GROSS -3.30, NET -4.14
# 2020-08-26, Close, 42.00
# 0.999 0.999
# 2020-08-26, BUY CREATE, 42.00
# 2020-08-27, BUY EXECUTED, Price: 42.07, Cost: 420.70, Comm 0.42
# 2020-08-27, Close, 41.63
# 0.999 0.999
# 2020-08-27, SELL CREATE, 41.63
# 2020-08-28, SELL EXECUTED, Price: 41.83, Cost: 420.70, Comm 0.42
# 2020-08-28, OPERATION PROFIT, GROSS -2.40, NET -3.24
# 2020-08-28, Close, 41.63
# 0.999 0.999
# 2020-08-28, BUY CREATE, 41.63
# 2020-08-31, BUY EXECUTED, Price: 41.83, Cost: 418.30, Comm 0.42
# 2020-08-31, Close, 41.83
# 0.999 0.999
# 2020-08-31, SELL CREATE, 41.83
# 2020-09-02, SELL EXECUTED, Price: 42.00, Cost: 418.30, Comm 0.42
# 2020-09-02, OPERATION PROFIT, GROSS 1.70, NET 0.86
# 2020-09-02, Close, 41.63
# 0.999 0.999
# 2020-09-02, BUY CREATE, 41.63
# 2020-09-03, BUY EXECUTED, Price: 41.70, Cost: 417.00, Comm 0.42
# 2020-09-03, Close, 41.50
# 0.999 0.999
# 2020-09-03, SELL CREATE, 41.50
# 2020-09-04, SELL EXECUTED, Price: 41.53, Cost: 417.00, Comm 0.42
# 2020-09-04, OPERATION PROFIT, GROSS -1.70, NET -2.53
# 2020-09-04, Close, 41.33
# 0.999 0.999
# 2020-09-04, BUY CREATE, 41.33
# 2020-09-07, BUY EXECUTED, Price: 41.20, Cost: 412.00, Comm 0.41
# 2020-09-07, Close, 40.93
# 0.999 0.999
# 2020-09-07, SELL CREATE, 40.93
# 2020-09-08, SELL EXECUTED, Price: 40.93, Cost: 412.00, Comm 0.41
# 2020-09-08, OPERATION PROFIT, GROSS -2.70, NET -3.52
# 2020-09-08, Close, 40.73
# 0.999 0.999
# 2020-09-08, BUY CREATE, 40.73
# 2020-09-09, BUY EXECUTED, Price: 41.00, Cost: 410.00, Comm 0.41
# 2020-09-09, Close, 41.33
# 0.999 0.999
# 2020-09-09, SELL CREATE, 41.33
# 2020-09-10, SELL EXECUTED, Price: 41.43, Cost: 410.00, Comm 0.41
# 2020-09-10, OPERATION PROFIT, GROSS 4.30, NET 3.48
# 2020-09-10, Close, 41.00
# 0.999 0.999
# 2020-09-10, BUY CREATE, 41.00
# 2020-09-11, BUY EXECUTED, Price: 40.97, Cost: 409.70, Comm 0.41
# 2020-09-11, Close, 41.30
# 0.999 0.999
# 2020-09-11, SELL CREATE, 41.30
# 2020-09-14, SELL EXECUTED, Price: 41.53, Cost: 409.70, Comm 0.42
# 2020-09-14, OPERATION PROFIT, GROSS 5.60, NET 4.78
# 2020-09-14, Close, 42.33
# 0.999 0.999
# 2020-09-14, BUY CREATE, 42.33
# 2020-09-15, BUY EXECUTED, Price: 42.33, Cost: 423.30, Comm 0.42
# 2020-09-15, Close, 42.17
# 0.999 0.999
# 2020-09-15, SELL CREATE, 42.17
# 2020-09-16, SELL EXECUTED, Price: 42.00, Cost: 423.30, Comm 0.42
# 2020-09-16, OPERATION PROFIT, GROSS -3.30, NET -4.14
# 2020-09-16, Close, 42.57
# 0.999 0.999
# 2020-09-16, BUY CREATE, 42.57
# 2020-09-17, BUY EXECUTED, Price: 42.33, Cost: 423.30, Comm 0.42
# 2020-09-17, Close, 44.17
# 0.999 0.999
# 2020-09-17, SELL CREATE, 44.17
# 2020-09-18, SELL EXECUTED, Price: 45.00, Cost: 423.30, Comm 0.45
# 2020-09-18, OPERATION PROFIT, GROSS 26.70, NET 25.83
# 2020-09-18, Close, 45.67
# 0.999 0.999
# 2020-09-18, BUY CREATE, 45.67
# 2020-09-21, BUY EXECUTED, Price: 46.30, Cost: 463.00, Comm 0.46
# 2020-09-21, Close, 45.63
# 0.999 0.999
# 2020-09-21, SELL CREATE, 45.63
# 2020-09-22, SELL EXECUTED, Price: 45.97, Cost: 463.00, Comm 0.46
# 2020-09-22, OPERATION PROFIT, GROSS -3.30, NET -4.22
# 2020-09-22, Close, 45.00
# 0.999 0.999
# 2020-09-22, BUY CREATE, 45.00
# 2020-09-23, BUY EXECUTED, Price: 45.17, Cost: 451.70, Comm 0.45
# 2020-09-23, Close, 45.00
# 0.999 0.999
# 2020-09-23, SELL CREATE, 45.00
# 2020-09-24, SELL EXECUTED, Price: 45.00, Cost: 451.70, Comm 0.45
# 2020-09-24, OPERATION PROFIT, GROSS -1.70, NET -2.60
# 2020-09-24, Close, 44.97
# 0.999 0.999
# 2020-09-24, BUY CREATE, 44.97
# 2020-09-25, BUY EXECUTED, Price: 44.73, Cost: 447.30, Comm 0.45
# 2020-09-25, Close, 44.93
# 0.999 0.999
# 2020-09-25, SELL CREATE, 44.93
# 2020-09-28, SELL EXECUTED, Price: 45.00, Cost: 447.30, Comm 0.45
# 2020-09-28, OPERATION PROFIT, GROSS 2.70, NET 1.80
# 2020-09-28, Close, 45.03
# 0.999 0.999
# 2020-09-28, BUY CREATE, 45.03
# 2020-09-29, BUY EXECUTED, Price: 45.20, Cost: 452.00, Comm 0.45
# 2020-09-29, Close, 44.83
# 0.999 0.999
# 2020-09-29, SELL CREATE, 44.83
# 2020-09-30, SELL EXECUTED, Price: 44.33, Cost: 452.00, Comm 0.44
# 2020-09-30, OPERATION PROFIT, GROSS -8.70, NET -9.60
# 2020-09-30, Close, 44.00
# 0.999 0.999
# 2020-09-30, BUY CREATE, 44.00
# 2020-10-02, BUY EXECUTED, Price: 44.00, Cost: 440.00, Comm 0.44
# 2020-10-02, Close, 43.67
# 0.999 0.999
# 2020-10-02, SELL CREATE, 43.67
# 2020-10-05, SELL EXECUTED, Price: 42.30, Cost: 440.00, Comm 0.42
# 2020-10-05, OPERATION PROFIT, GROSS -17.00, NET -17.86
# 2020-10-05, Close, 40.93
# 0.999 0.999
# 2020-10-05, BUY CREATE, 40.93
# 2020-10-06, BUY EXECUTED, Price: 40.33, Cost: 403.30, Comm 0.40
# 2020-10-06, Close, 40.47
# 0.999 0.999
# 2020-10-06, SELL CREATE, 40.47
# 2020-10-07, SELL EXECUTED, Price: 40.20, Cost: 403.30, Comm 0.40
# 2020-10-07, OPERATION PROFIT, GROSS -1.30, NET -2.11
# 2020-10-07, Close, 39.67
# 0.999 0.999
# 2020-10-07, BUY CREATE, 39.67
# 2020-10-08, BUY EXECUTED, Price: 40.00, Cost: 400.00, Comm 0.40
# 2020-10-08, Close, 40.73
# 0.999 0.999
# 2020-10-08, SELL CREATE, 40.73
# 2020-10-09, SELL EXECUTED, Price: 41.00, Cost: 400.00, Comm 0.41
# 2020-10-09, OPERATION PROFIT, GROSS 10.00, NET 9.19
# 2020-10-09, Close, 41.60
# 0.999 0.999
# 2020-10-09, BUY CREATE, 41.60
# 2020-10-12, BUY EXECUTED, Price: 41.67, Cost: 416.70, Comm 0.42
# 2020-10-12, Close, 41.33
# 0.991 0.999
# 2020-10-12, SELL CREATE, 41.33
# 2020-10-13, SELL EXECUTED, Price: 41.33, Cost: 416.70, Comm 0.41
# 2020-10-13, OPERATION PROFIT, GROSS -3.40, NET -4.23
# 2020-10-13, Close, 40.67
# 0.991 0.991
# 2020-10-13, BUY CREATE, 40.67
# 2020-10-14, BUY EXECUTED, Price: 40.73, Cost: 407.30, Comm 0.41
# 2020-10-14, Close, 41.50
# 0.991 0.991
# 2020-10-14, SELL CREATE, 41.50
# 2020-10-15, SELL EXECUTED, Price: 41.57, Cost: 407.30, Comm 0.42
# 2020-10-15, OPERATION PROFIT, GROSS 8.40, NET 7.58
# 2020-10-15, Close, 41.50
# 0.991 0.991
# 2020-10-15, BUY CREATE, 41.50
# 2020-10-16, BUY EXECUTED, Price: 41.50, Cost: 415.00, Comm 0.42
# 2020-10-16, Close, 41.30
# 0.991 0.991
# 2020-10-16, SELL CREATE, 41.30
# 2020-10-19, SELL EXECUTED, Price: 41.50, Cost: 415.00, Comm 0.42
# 2020-10-19, OPERATION PROFIT, GROSS 0.00, NET -0.83
# 2020-10-19, Close, 41.53
# 0.991 0.991
# 2020-10-19, BUY CREATE, 41.53
# 2020-10-20, BUY EXECUTED, Price: 41.50, Cost: 415.00, Comm 0.42
# 2020-10-20, Close, 41.80
# 0.991 0.991
# 2020-10-20, SELL CREATE, 41.80
# 2020-10-21, SELL EXECUTED, Price: 41.67, Cost: 415.00, Comm 0.42
# 2020-10-21, OPERATION PROFIT, GROSS 1.70, NET 0.87
# 2020-10-21, Close, 41.03
# 0.991 0.991
# 2020-10-21, BUY CREATE, 41.03
# 2020-10-22, BUY EXECUTED, Price: 40.00, Cost: 400.00, Comm 0.40
# 2020-10-22, Close, 40.50
# 0.991 0.991
# 2020-10-22, SELL CREATE, 40.50
# 2020-10-23, SELL EXECUTED, Price: 41.00, Cost: 400.00, Comm 0.41
# 2020-10-23, OPERATION PROFIT, GROSS 10.00, NET 9.19
# 2020-10-23, Close, 41.00
# 0.991 0.991
# 2020-10-23, BUY CREATE, 41.00
# 2020-10-26, BUY EXECUTED, Price: 40.37, Cost: 403.70, Comm 0.40
# 2020-10-26, Close, 40.33
# 0.991 0.991
# 2020-10-26, SELL CREATE, 40.33
# 2020-10-27, SELL EXECUTED, Price: 40.80, Cost: 403.70, Comm 0.41
# 2020-10-27, OPERATION PROFIT, GROSS 4.30, NET 3.49
# 2020-10-27, Close, 40.30
# 0.991 0.991
# 2020-10-27, BUY CREATE, 40.30
# 2020-10-28, BUY EXECUTED, Price: 40.50, Cost: 405.00, Comm 0.41
# 2020-10-28, Close, 40.30
# 0.991 0.991
# 2020-10-28, SELL CREATE, 40.30
# 2020-10-29, SELL EXECUTED, Price: 40.07, Cost: 405.00, Comm 0.40
# 2020-10-29, OPERATION PROFIT, GROSS -4.30, NET -5.11
# 2020-10-29, Close, 40.63
# 0.991 0.991
# 2020-10-29, BUY CREATE, 40.63
# 2020-11-02, BUY EXECUTED, Price: 40.00, Cost: 400.00, Comm 0.40
# 2020-11-02, Close, 40.07
# 0.991 0.991
# 2020-11-02, SELL CREATE, 40.07
# 2020-11-03, SELL EXECUTED, Price: 40.63, Cost: 400.00, Comm 0.41
# 2020-11-03, OPERATION PROFIT, GROSS 6.30, NET 5.49
# 2020-11-03, Close, 40.33
# 0.991 0.991
# 2020-11-03, BUY CREATE, 40.33
# 2020-11-04, BUY EXECUTED, Price: 40.43, Cost: 404.30, Comm 0.40
# 2020-11-04, Close, 40.67
# 0.991 0.991
# 2020-11-04, SELL CREATE, 40.67
# 2020-11-05, SELL EXECUTED, Price: 40.87, Cost: 404.30, Comm 0.41
# 2020-11-05, OPERATION PROFIT, GROSS 4.40, NET 3.59
# 2020-11-05, Close, 40.90
# 0.991 0.991
# 2020-11-05, BUY CREATE, 40.90
# 2020-11-06, BUY EXECUTED, Price: 41.00, Cost: 410.00, Comm 0.41
# 2020-11-06, Close, 41.50
# 0.991 0.991
# 2020-11-06, SELL CREATE, 41.50
# 2020-11-09, SELL EXECUTED, Price: 41.67, Cost: 410.00, Comm 0.42
# 2020-11-09, OPERATION PROFIT, GROSS 6.70, NET 5.87
# 2020-11-09, Close, 41.50
# 0.991 0.991
# 2020-11-09, BUY CREATE, 41.50
# 2020-11-10, BUY EXECUTED, Price: 41.70, Cost: 417.00, Comm 0.42
# 2020-11-10, Close, 42.47
# 0.991 0.991
# 2020-11-10, SELL CREATE, 42.47
# 2020-11-11, SELL EXECUTED, Price: 42.67, Cost: 417.00, Comm 0.43
# 2020-11-11, OPERATION PROFIT, GROSS 9.70, NET 8.86
# 2020-11-11, Close, 42.67
# 0.991 0.991
# 2020-11-11, BUY CREATE, 42.67
# 2020-11-12, BUY EXECUTED, Price: 41.67, Cost: 416.70, Comm 0.42
# 2020-11-12, Close, 41.47
# 0.991 0.991
# 2020-11-12, SELL CREATE, 41.47
# 2020-11-13, SELL EXECUTED, Price: 41.33, Cost: 416.70, Comm 0.41
# 2020-11-13, OPERATION PROFIT, GROSS -3.40, NET -4.23
# 2020-11-13, Close, 41.83
# 1.0 0.991
# 2020-11-13, BUY CREATE, 41.83
# 2020-11-16, BUY EXECUTED, Price: 42.00, Cost: 420.00, Comm 0.42
# 2020-11-16, Close, 41.33
# 1.0 1.0
# 2020-11-16, SELL CREATE, 41.33
# 2020-11-17, SELL EXECUTED, Price: 41.33, Cost: 420.00, Comm 0.41
# 2020-11-17, OPERATION PROFIT, GROSS -6.70, NET -7.53
# 2020-11-17, Close, 41.67
# 1.0 1.0
# 2020-11-17, BUY CREATE, 41.67
# 2020-11-18, BUY EXECUTED, Price: 41.67, Cost: 416.70, Comm 0.42
# 2020-11-18, Close, 41.47
# 1.0 1.0
# 2020-11-18, SELL CREATE, 41.47
# 2020-11-19, SELL EXECUTED, Price: 41.50, Cost: 416.70, Comm 0.42
# 2020-11-19, OPERATION PROFIT, GROSS -1.70, NET -2.53
# 2020-11-19, Close, 41.40
# 1.0 1.0
# 2020-11-19, BUY CREATE, 41.40
# 2020-11-20, BUY EXECUTED, Price: 41.67, Cost: 416.70, Comm 0.42
# 2020-11-20, Close, 41.40
# 1.0 1.0
# 2020-11-20, SELL CREATE, 41.40
# 2020-11-23, SELL EXECUTED, Price: 41.67, Cost: 416.70, Comm 0.42
# 2020-11-23, OPERATION PROFIT, GROSS 0.00, NET -0.83
# 2020-11-23, Close, 41.50
# 1.0 1.0
# 2020-11-23, BUY CREATE, 41.50
# 2020-11-24, BUY EXECUTED, Price: 41.47, Cost: 414.70, Comm 0.41
# 2020-11-24, Close, 41.43
# 1.0 1.0
# 2020-11-24, SELL CREATE, 41.43
# 2020-11-25, SELL EXECUTED, Price: 41.40, Cost: 414.70, Comm 0.41
# 2020-11-25, OPERATION PROFIT, GROSS -0.70, NET -1.53
# 2020-11-25, Close, 41.40
# 1.0 1.0
# 2020-11-25, BUY CREATE, 41.40
# 2020-11-26, BUY EXECUTED, Price: 41.40, Cost: 414.00, Comm 0.41
# 2020-11-26, Close, 41.43
# 1.0 1.0
# 2020-11-26, SELL CREATE, 41.43
# 2020-11-27, SELL EXECUTED, Price: 41.40, Cost: 414.00, Comm 0.41
# 2020-11-27, OPERATION PROFIT, GROSS 0.00, NET -0.83
# 2020-11-27, Close, 41.73
# 1.0 1.0
# 2020-11-27, BUY CREATE, 41.73
# 2020-11-30, BUY EXECUTED, Price: 41.67, Cost: 416.70, Comm 0.42
# 2020-11-30, Close, 42.33
# 1.0 1.0
# 2020-11-30, SELL CREATE, 42.33
# 2020-12-01, SELL EXECUTED, Price: 42.33, Cost: 416.70, Comm 0.42
# 2020-12-01, OPERATION PROFIT, GROSS 6.60, NET 5.76
# 2020-12-01, Close, 42.97
# 1.0 1.0
# 2020-12-01, BUY CREATE, 42.97
# 2020-12-02, BUY EXECUTED, Price: 43.10, Cost: 431.00, Comm 0.43
# 2020-12-02, Close, 43.47
# 1.0 1.0
# 2020-12-02, SELL CREATE, 43.47
# 2020-12-03, SELL EXECUTED, Price: 43.63, Cost: 431.00, Comm 0.44
# 2020-12-03, OPERATION PROFIT, GROSS 5.30, NET 4.43
# 2020-12-03, Close, 43.33
# 1.0 1.0
# 2020-12-03, BUY CREATE, 43.33
# 2020-12-04, BUY EXECUTED, Price: 43.33, Cost: 433.30, Comm 0.43
# 2020-12-04, Close, 43.97
# 1.0 1.0
# 2020-12-04, SELL CREATE, 43.97
# 2020-12-07, SELL EXECUTED, Price: 44.20, Cost: 433.30, Comm 0.44
# 2020-12-07, OPERATION PROFIT, GROSS 8.70, NET 7.82
# 2020-12-07, Close, 45.30
# 1.0 1.0
# 2020-12-07, BUY CREATE, 45.30
# 2020-12-08, BUY EXECUTED, Price: 45.33, Cost: 453.30, Comm 0.45
# 2020-12-08, Close, 46.47
# 1.0 1.0
# 2020-12-08, SELL CREATE, 46.47
# 2020-12-09, SELL EXECUTED, Price: 46.60, Cost: 453.30, Comm 0.47
# 2020-12-09, OPERATION PROFIT, GROSS 12.70, NET 11.78
# 2020-12-09, Close, 46.50
# 1.0 1.0
# 2020-12-09, BUY CREATE, 46.50
# 2020-12-10, BUY EXECUTED, Price: 46.63, Cost: 466.30, Comm 0.47
# 2020-12-10, Close, 45.80
# 1.0 1.0
# 2020-12-10, SELL CREATE, 45.80
# 2020-12-11, SELL EXECUTED, Price: 45.83, Cost: 466.30, Comm 0.46
# 2020-12-11, OPERATION PROFIT, GROSS -8.00, NET -8.92
# 2020-12-11, Close, 45.20
# 1.0 1.0
# 2020-12-11, BUY CREATE, 45.20
# 2020-12-14, BUY EXECUTED, Price: 45.00, Cost: 450.00, Comm 0.45
# 2020-12-14, Close, 45.47
# 1.0 1.0
# 2020-12-14, SELL CREATE, 45.47
# 2020-12-15, SELL EXECUTED, Price: 45.63, Cost: 450.00, Comm 0.46
# 2020-12-15, OPERATION PROFIT, GROSS 6.30, NET 5.39
# 2020-12-15, Close, 44.97
# 1.0 1.0
# 2020-12-15, BUY CREATE, 44.97
# 2020-12-16, BUY EXECUTED, Price: 44.83, Cost: 448.30, Comm 0.45
# 2020-12-16, Close, 44.63
# 1.0 1.0
# 2020-12-16, SELL CREATE, 44.63
# 2020-12-17, SELL EXECUTED, Price: 44.63, Cost: 448.30, Comm 0.45
# 2020-12-17, OPERATION PROFIT, GROSS -2.00, NET -2.89
# 2020-12-17, Close, 44.50
# 1.0 1.0
# 2020-12-17, BUY CREATE, 44.50
# 2020-12-18, BUY EXECUTED, Price: 44.33, Cost: 443.30, Comm 0.44
# 2020-12-18, Close, 44.50
# 1.0 1.0
# 2020-12-18, SELL CREATE, 44.50
# 2020-12-21, SELL EXECUTED, Price: 44.50, Cost: 443.30, Comm 0.45
# 2020-12-21, OPERATION PROFIT, GROSS 1.70, NET 0.81
# 2020-12-21, Close, 43.97
# 1.0 1.0
# 2020-12-21, BUY CREATE, 43.97
# 2020-12-22, BUY EXECUTED, Price: 43.87, Cost: 438.70, Comm 0.44
# 2020-12-22, Close, 43.57
# 1.0 1.0
# 2020-12-22, SELL CREATE, 43.57
# 2020-12-23, SELL EXECUTED, Price: 43.37, Cost: 438.70, Comm 0.43
# 2020-12-23, OPERATION PROFIT, GROSS -5.00, NET -5.87
# 2020-12-23, Close, 43.80
# 1.0 1.0
# 2020-12-23, BUY CREATE, 43.80
# 2020-12-24, BUY EXECUTED, Price: 44.00, Cost: 440.00, Comm 0.44
# 2020-12-24, Close, 44.40
# 1.0 1.0
# 2020-12-24, SELL CREATE, 44.40
# 2020-12-28, SELL EXECUTED, Price: 44.67, Cost: 440.00, Comm 0.45
# 2020-12-28, OPERATION PROFIT, GROSS 6.70, NET 5.81
# 2020-12-28, Close, 44.83
# 1.0 1.0
# 2020-12-28, BUY CREATE, 44.83
# 2020-12-30, BUY EXECUTED, Price: 44.83, Cost: 448.30, Comm 0.45
# 2020-12-30, Close, 44.97
# 1.0 1.0
# 2020-12-30, SELL CREATE, 44.97
# 2020-12-31, SELL EXECUTED, Price: 44.83, Cost: 448.30, Comm 0.45
# 2020-12-31, OPERATION PROFIT, GROSS 0.00, NET -0.90
# 2020-12-31, Close, 46.00
# 1.0 1.0
# 2020-12-31, BUY CREATE, 46.00
# 2021-01-04, BUY EXECUTED, Price: 46.00, Cost: 460.00, Comm 0.46
# 2021-01-04, Close, 47.00
# 1.0 1.0
# 2021-01-04, SELL CREATE, 47.00
# 2021-01-05, SELL EXECUTED, Price: 47.03, Cost: 460.00, Comm 0.47
# 2021-01-05, OPERATION PROFIT, GROSS 10.30, NET 9.37
# 2021-01-05, Close, 47.57
# 1.0 1.0
# 2021-01-05, BUY CREATE, 47.57
# 2021-01-06, BUY EXECUTED, Price: 47.50, Cost: 475.00, Comm 0.48
# 2021-01-06, Close, 47.23
# 1.0 1.0
# 2021-01-06, SELL CREATE, 47.23
# 2021-01-07, SELL EXECUTED, Price: 47.17, Cost: 475.00, Comm 0.47
# 2021-01-07, OPERATION PROFIT, GROSS -3.30, NET -4.25
# 2021-01-07, Close, 47.17
# 1.0 1.0
# 2021-01-07, BUY CREATE, 47.17
# 2021-01-08, BUY EXECUTED, Price: 47.17, Cost: 471.70, Comm 0.47
# 2021-01-08, Close, 47.25
# 1.0 1.0
# 2021-01-08, SELL CREATE, 47.25
# 2021-01-11, SELL EXECUTED, Price: 47.33, Cost: 471.70, Comm 0.47
# 2021-01-11, OPERATION PROFIT, GROSS 1.60, NET 0.65
# 2021-01-11, Close, 47.00
# 1.0 1.0
# 2021-01-11, BUY CREATE, 47.00
# 2021-01-12, BUY EXECUTED, Price: 47.00, Cost: 470.00, Comm 0.47
# 2021-01-12, Close, 46.67
# 1.0 1.0
# 2021-01-12, SELL CREATE, 46.67
# 2021-01-13, SELL EXECUTED, Price: 46.67, Cost: 470.00, Comm 0.47
# 2021-01-13, OPERATION PROFIT, GROSS -3.30, NET -4.24
# 2021-01-13, Close, 46.25
# 1.0 1.0
# 2021-01-13, BUY CREATE, 46.25
# 2021-01-15, BUY EXECUTED, Price: 46.00, Cost: 460.00, Comm 0.46
# 2021-01-15, Close, 47.67
# 1.0 1.0
# 2021-01-15, SELL CREATE, 47.67
# 2021-01-18, SELL EXECUTED, Price: 47.67, Cost: 460.00, Comm 0.48
# 2021-01-18, OPERATION PROFIT, GROSS 16.70, NET 15.76
# 2021-01-18, Close, 49.00
# 1.0 1.0
# 2021-01-18, BUY CREATE, 49.00
# 2021-01-19, BUY EXECUTED, Price: 49.33, Cost: 493.30, Comm 0.49
# 2021-01-19, Close, 53.00
# 1.0 1.0
# 2021-01-19, SELL CREATE, 53.00
# 2021-01-20, SELL EXECUTED, Price: 55.00, Cost: 493.30, Comm 0.55
# 2021-01-20, OPERATION PROFIT, GROSS 56.70, NET 55.66
# 2021-01-20, Close, 55.17
# 1.0 1.0
# 2021-01-20, BUY CREATE, 55.17
# 2021-01-21, BUY EXECUTED, Price: 55.67, Cost: 556.70, Comm 0.56
# 2021-01-21, Close, 55.33
# 1.0 1.0
# 2021-01-21, SELL CREATE, 55.33
# 2021-01-22, SELL EXECUTED, Price: 55.42, Cost: 556.70, Comm 0.55
# 2021-01-22, OPERATION PROFIT, GROSS -2.50, NET -3.61
# 2021-01-22, Close, 54.67
# 1.0 1.0
# 2021-01-22, BUY CREATE, 54.67
# 2021-01-25, BUY EXECUTED, Price: 55.00, Cost: 550.00, Comm 0.55
# 2021-01-25, Close, 58.00
# 1.0 1.0
# 2021-01-25, SELL CREATE, 58.00
# 2021-01-26, SELL EXECUTED, Price: 58.17, Cost: 550.00, Comm 0.58
# 2021-01-26, OPERATION PROFIT, GROSS 31.70, NET 30.57
# 2021-01-26, Close, 56.67
# 1.0 1.0
# 2021-01-26, BUY CREATE, 56.67
# 2021-01-27, BUY EXECUTED, Price: 56.67, Cost: 566.70, Comm 0.57
# 2021-01-27, Close, 55.67
# 1.0 1.0
# 2021-01-27, SELL CREATE, 55.67
# 2021-01-29, SELL EXECUTED, Price: 68.50, Cost: 566.70, Comm 0.69
# 2021-01-29, OPERATION PROFIT, GROSS 118.30, NET 117.05
# 2021-01-29, Close, 67.67
# 1.0 1.0
# 2021-01-29, BUY CREATE, 67.67
# 2021-02-01, BUY EXECUTED, Price: 69.67, Cost: 696.70, Comm 0.70
# 2021-02-01, Close, 65.00
# 1.0 1.0
# 2021-02-01, SELL CREATE, 65.00
# 2021-02-02, SELL EXECUTED, Price: 65.33, Cost: 696.70, Comm 0.65
# 2021-02-02, OPERATION PROFIT, GROSS -43.40, NET -44.75
# 2021-02-02, Close, 60.50
# 1.0 1.0
# 2021-02-02, BUY CREATE, 60.50
# 2021-02-03, BUY EXECUTED, Price: 61.00, Cost: 610.00, Comm 0.61
# 2021-02-03, Close, 60.17
# 1.0 1.0
# 2021-02-03, SELL CREATE, 60.17
# 2021-02-05, SELL EXECUTED, Price: 61.00, Cost: 610.00, Comm 0.61
# 2021-02-05, OPERATION PROFIT, GROSS 0.00, NET -1.22
# 2021-02-05, Close, 59.33
# 1.0 1.0
# 2021-02-05, BUY CREATE, 59.33
# 2021-02-08, BUY EXECUTED, Price: 60.00, Cost: 600.00, Comm 0.60
# 2021-02-08, Close, 56.33
# 1.0 1.0
# 2021-02-08, SELL CREATE, 56.33
# 2021-02-09, SELL EXECUTED, Price: 56.67, Cost: 600.00, Comm 0.57
# 2021-02-09, OPERATION PROFIT, GROSS -33.30, NET -34.47
# 2021-02-09, Close, 55.67
# 1.0 1.0
# 2021-02-09, BUY CREATE, 55.67
# 2021-02-10, BUY EXECUTED, Price: 55.83, Cost: 558.30, Comm 0.56
# 2021-02-10, Close, 54.67
# 1.0 1.0
# 2021-02-10, SELL CREATE, 54.67
# 2021-02-11, SELL EXECUTED, Price: 55.00, Cost: 558.30, Comm 0.55
# 2021-02-11, OPERATION PROFIT, GROSS -8.30, NET -9.41
# 2021-02-11, Close, 55.17
# 1.0 1.0
# 2021-02-11, BUY CREATE, 55.17
# 2021-02-12, BUY EXECUTED, Price: 55.33, Cost: 553.30, Comm 0.55
# 2021-02-12, Close, 58.00
# 1.0 1.0
# 2021-02-12, SELL CREATE, 58.00
# 2021-02-15, SELL EXECUTED, Price: 58.67, Cost: 553.30, Comm 0.59
# 2021-02-15, OPERATION PROFIT, GROSS 33.40, NET 32.26
# 2021-02-15, Close, 56.17
# 1.0 1.0
# 2021-02-15, BUY CREATE, 56.17
# 2021-02-16, BUY EXECUTED, Price: 56.58, Cost: 565.80, Comm 0.57
# 2021-02-16, Close, 54.92
# 1.0 1.0
# 2021-02-16, SELL CREATE, 54.92
# 2021-02-17, SELL EXECUTED, Price: 54.92, Cost: 565.80, Comm 0.55
# 2021-02-17, OPERATION PROFIT, GROSS -16.60, NET -17.71
# 2021-02-17, Close, 53.50
# 1.0 1.0
# 2021-02-17, BUY CREATE, 53.50
# 2021-02-18, BUY EXECUTED, Price: 54.33, Cost: 543.30, Comm 0.54
# 2021-02-18, Close, 53.33
# 1.0 1.0
# 2021-02-18, SELL CREATE, 53.33
# 2021-02-19, SELL EXECUTED, Price: 53.33, Cost: 543.30, Comm 0.53
# 2021-02-19, OPERATION PROFIT, GROSS -10.00, NET -11.08
# 2021-02-19, Close, 53.33
# 1.0 1.0
# 2021-02-19, BUY CREATE, 53.33
# 2021-02-22, BUY EXECUTED, Price: 53.33, Cost: 533.30, Comm 0.53
# 2021-02-22, Close, 52.83
# 1.0 1.0
# 2021-02-22, SELL CREATE, 52.83
# 2021-02-23, SELL EXECUTED, Price: 53.25, Cost: 533.30, Comm 0.53
# 2021-02-23, OPERATION PROFIT, GROSS -0.80, NET -1.87
# 2021-02-23, Close, 51.33
# 1.0 1.0
# 2021-02-23, BUY CREATE, 51.33
# 2021-02-24, BUY EXECUTED, Price: 51.67, Cost: 516.70, Comm 0.52
# 2021-02-24, Close, 51.33
# 1.0 1.0
# 2021-02-24, SELL CREATE, 51.33
# 2021-02-25, SELL EXECUTED, Price: 51.33, Cost: 516.70, Comm 0.51
# 2021-02-25, OPERATION PROFIT, GROSS -3.40, NET -4.43
# 2021-02-25, Close, 52.00
# 1.0 1.0
# 2021-02-25, BUY CREATE, 52.00
# 2021-03-01, BUY EXECUTED, Price: 53.00, Cost: 530.00, Comm 0.53
# 2021-03-01, Close, 52.08
# 0.988 1.0
# 2021-03-01, SELL CREATE, 52.08
# 2021-03-02, SELL EXECUTED, Price: 52.00, Cost: 530.00, Comm 0.52
# 2021-03-02, OPERATION PROFIT, GROSS -10.00, NET -11.05
# 2021-03-02, Close, 51.67
# 0.988 0.988
# 2021-03-02, BUY CREATE, 51.67
# 2021-03-03, BUY EXECUTED, Price: 52.50, Cost: 525.00, Comm 0.53
# 2021-03-03, Close, 50.92
# 0.988 0.988
# 2021-03-03, SELL CREATE, 50.92
# 2021-03-04, SELL EXECUTED, Price: 51.33, Cost: 525.00, Comm 0.51
# 2021-03-04, OPERATION PROFIT, GROSS -11.70, NET -12.74
# 2021-03-04, Close, 50.33
# 0.988 0.988
# 2021-03-04, BUY CREATE, 50.33
# 2021-03-05, BUY EXECUTED, Price: 50.33, Cost: 503.30, Comm 0.50
# 2021-03-05, Close, 50.33
# 0.988 0.988
# 2021-03-05, SELL CREATE, 50.33
# 2021-03-08, SELL EXECUTED, Price: 51.33, Cost: 503.30, Comm 0.51
# 2021-03-08, OPERATION PROFIT, GROSS 10.00, NET 8.98
# 2021-03-08, Close, 51.17
# 0.988 0.988
# 2021-03-08, BUY CREATE, 51.17
# 2021-03-09, BUY EXECUTED, Price: 51.33, Cost: 513.30, Comm 0.51
# 2021-03-09, Close, 51.67
# 0.988 0.988
# 2021-03-09, SELL CREATE, 51.67
# 2021-03-10, SELL EXECUTED, Price: 52.33, Cost: 513.30, Comm 0.52
# 2021-03-10, OPERATION PROFIT, GROSS 10.00, NET 8.96
# 2021-03-10, Close, 51.33
# 0.988 0.988
# 2021-03-10, BUY CREATE, 51.33
# 2021-03-12, BUY EXECUTED, Price: 51.67, Cost: 516.70, Comm 0.52
# 2021-03-12, Close, 51.58
# 0.988 0.988
# 2021-03-12, SELL CREATE, 51.58
# 2021-03-15, SELL EXECUTED, Price: 51.67, Cost: 516.70, Comm 0.52
# 2021-03-15, OPERATION PROFIT, GROSS 0.00, NET -1.03
# 2021-03-15, Close, 51.67
# 0.988 0.988
# 2021-03-15, BUY CREATE, 51.67
# 2021-03-16, BUY EXECUTED, Price: 52.00, Cost: 520.00, Comm 0.52
# 2021-03-16, Close, 51.50
# 0.988 0.988
# 2021-03-16, SELL CREATE, 51.50
# 2021-03-17, SELL EXECUTED, Price: 51.58, Cost: 520.00, Comm 0.52
# 2021-03-17, OPERATION PROFIT, GROSS -4.20, NET -5.24
# 2021-03-17, Close, 51.50
# 0.988 0.988
# 2021-03-17, BUY CREATE, 51.50
# 2021-03-23, BUY EXECUTED, Price: 54.90, Cost: 549.00, Comm 0.55
# 2021-03-23, Close, 51.30
# 0.988 0.988
# 2021-03-23, SELL CREATE, 51.30
# 2021-03-24, SELL EXECUTED, Price: 51.80, Cost: 549.00, Comm 0.52
# 2021-03-24, OPERATION PROFIT, GROSS -31.00, NET -32.07
# 2021-03-24, Close, 54.90
# 0.988 0.988
# 2021-03-24, BUY CREATE, 54.90
# 2021-03-25, BUY EXECUTED, Price: 55.00, Cost: 550.00, Comm 0.55
# 2021-03-25, Close, 54.70
# 0.988 0.988
# 2021-03-25, SELL CREATE, 54.70
# 2021-03-26, SELL EXECUTED, Price: 55.00, Cost: 550.00, Comm 0.55
# 2021-03-26, OPERATION PROFIT, GROSS 0.00, NET -1.10
# 2021-03-26, Close, 56.80
# 0.988 0.988
# 2021-03-26, BUY CREATE, 56.80
# 2021-03-29, BUY EXECUTED, Price: 57.00, Cost: 570.00, Comm 0.57
# 2021-03-29, Close, 56.70
# 0.988 0.988
# 2021-03-29, SELL CREATE, 56.70
# 2021-03-30, SELL EXECUTED, Price: 57.00, Cost: 570.00, Comm 0.57
# 2021-03-30, OPERATION PROFIT, GROSS 0.00, NET -1.14
# 2021-03-30, Close, 56.80
# 0.988 0.988
# 2021-03-30, BUY CREATE, 56.80
# 2021-03-31, BUY EXECUTED, Price: 54.30, Cost: 543.00, Comm 0.54
# 2021-03-31, Close, 54.00
# 0.988 0.988
# 2021-03-31, SELL CREATE, 54.00
# 2021-04-01, SELL EXECUTED, Price: 53.80, Cost: 543.00, Comm 0.54
# 2021-04-01, OPERATION PROFIT, GROSS -5.00, NET -6.08
# 2021-04-01, Close, 53.50
# 0.988 0.988
# 2021-04-01, BUY CREATE, 53.50
# 2021-04-05, BUY EXECUTED, Price: 53.50, Cost: 535.00, Comm 0.54
# 2021-04-05, Close, 52.30
# 0.988 0.988
# 2021-04-05, SELL CREATE, 52.30
# 2021-04-06, SELL EXECUTED, Price: 52.50, Cost: 535.00, Comm 0.53
# 2021-04-06, OPERATION PROFIT, GROSS -10.00, NET -11.06
# 2021-04-06, Close, 54.00
# 0.988 0.988
# 2021-04-06, BUY CREATE, 54.00
# 2021-04-07, BUY EXECUTED, Price: 54.00, Cost: 540.00, Comm 0.54
# 2021-04-07, Close, 53.90
# 0.988 0.988
# 2021-04-07, SELL CREATE, 53.90
# 2021-04-08, SELL EXECUTED, Price: 53.90, Cost: 540.00, Comm 0.54
# 2021-04-08, OPERATION PROFIT, GROSS -1.00, NET -2.08
# 2021-04-08, Close, 55.80
# 0.988 0.988
# 2021-04-08, BUY CREATE, 55.80
# 2021-04-09, BUY EXECUTED, Price: 56.00, Cost: 560.00, Comm 0.56
# 2021-04-09, Close, 55.30
# 0.988 0.988
# 2021-04-09, SELL CREATE, 55.30
# 2021-04-12, SELL EXECUTED, Price: 55.90, Cost: 560.00, Comm 0.56
# 2021-04-12, OPERATION PROFIT, GROSS -1.00, NET -2.12
# 2021-04-12, Close, 54.50
# 0.988 0.988
# 2021-04-12, BUY CREATE, 54.50
# 2021-04-15, BUY EXECUTED, Price: 55.00, Cost: 550.00, Comm 0.55
# 2021-04-15, Close, 54.10
# 0.988 0.988
# 2021-04-15, SELL CREATE, 54.10
# 2021-04-16, SELL EXECUTED, Price: 54.80, Cost: 550.00, Comm 0.55
# 2021-04-16, OPERATION PROFIT, GROSS -2.00, NET -3.10
# 2021-04-16, Close, 54.00
# 0.988 0.988
# 2021-04-16, BUY CREATE, 54.00
# 2021-04-19, BUY EXECUTED, Price: 54.00, Cost: 540.00, Comm 0.54
# 2021-04-19, Close, 53.50
# 0.988 0.988
# 2021-04-19, SELL CREATE, 53.50
# 2021-04-20, SELL EXECUTED, Price: 54.00, Cost: 540.00, Comm 0.54
# 2021-04-20, OPERATION PROFIT, GROSS 0.00, NET -1.08
# 2021-04-20, Close, 51.70
# 0.988 0.988
# 2021-04-20, BUY CREATE, 51.70
# 2021-04-21, BUY EXECUTED, Price: 51.50, Cost: 515.00, Comm 0.52
# 2021-04-21, Close, 51.50
# 0.988 0.988
# 2021-04-21, SELL CREATE, 51.50
# 2021-04-22, SELL EXECUTED, Price: 51.80, Cost: 515.00, Comm 0.52
# 2021-04-22, OPERATION PROFIT, GROSS 3.00, NET 1.97
# 2021-04-22, Close, 51.00
# 0.988 0.988
# 2021-04-22, BUY CREATE, 51.00
# 2021-04-23, BUY EXECUTED, Price: 50.50, Cost: 505.00, Comm 0.51
# 2021-04-23, Close, 50.20
# 0.988 0.988
# 2021-04-23, SELL CREATE, 50.20
# 2021-04-27, SELL EXECUTED, Price: 49.80, Cost: 505.00, Comm 0.50
# 2021-04-27, OPERATION PROFIT, GROSS -7.00, NET -8.00
# 2021-04-27, Close, 48.50
# 0.988 0.988
# 2021-04-27, BUY CREATE, 48.50
# 2021-04-28, BUY EXECUTED, Price: 48.30, Cost: 483.00, Comm 0.48
# 2021-04-28, Close, 49.60
# 0.988 0.988
# 2021-04-28, SELL CREATE, 49.60
# 2021-04-29, SELL EXECUTED, Price: 49.60, Cost: 483.00, Comm 0.50
# 2021-04-29, OPERATION PROFIT, GROSS 13.00, NET 12.02
# 2021-04-29, Close, 48.90
# 0.988 0.988
# 2021-04-29, BUY CREATE, 48.90
# 2021-04-30, BUY EXECUTED, Price: 48.90, Cost: 489.00, Comm 0.49
# 2021-04-30, Close, 50.00
# 0.988 0.988
# 2021-04-30, SELL CREATE, 50.00
# 2021-05-03, SELL EXECUTED, Price: 50.00, Cost: 489.00, Comm 0.50
# 2021-05-03, OPERATION PROFIT, GROSS 11.00, NET 10.01
# 2021-05-03, Close, 49.50
# 0.988 0.988
# 2021-05-03, BUY CREATE, 49.50
# 2021-05-04, BUY EXECUTED, Price: 49.20, Cost: 492.00, Comm 0.49
# 2021-05-04, Close, 49.60
# 0.988 0.988
# 2021-05-04, SELL CREATE, 49.60
# 2021-05-05, SELL EXECUTED, Price: 50.00, Cost: 492.00, Comm 0.50
# 2021-05-05, OPERATION PROFIT, GROSS 8.00, NET 7.01
# 2021-05-05, Close, 49.80
# 0.988 0.988
# 2021-05-05, BUY CREATE, 49.80
# 2021-05-06, BUY EXECUTED, Price: 50.00, Cost: 500.00, Comm 0.50
# 2021-05-06, Close, 50.10
# 0.988 0.988
# 2021-05-06, SELL CREATE, 50.10
# 2021-05-07, SELL EXECUTED, Price: 50.20, Cost: 500.00, Comm 0.50
# 2021-05-07, OPERATION PROFIT, GROSS 2.00, NET 1.00
# 2021-05-07, Close, 51.00
# 0.988 0.988
# 2021-05-07, BUY CREATE, 51.00
# 2021-05-10, BUY EXECUTED, Price: 51.10, Cost: 511.00, Comm 0.51
# 2021-05-10, Close, 49.80
# 0.988 0.988
# 2021-05-10, SELL CREATE, 49.80
# 2021-05-11, SELL EXECUTED, Price: 49.90, Cost: 511.00, Comm 0.50
# 2021-05-11, OPERATION PROFIT, GROSS -12.00, NET -13.01
# 2021-05-11, Close, 49.80
# 0.988 0.988
# 2021-05-11, BUY CREATE, 49.80
# 2021-05-12, BUY EXECUTED, Price: 50.10, Cost: 501.00, Comm 0.50
# 2021-05-12, Close, 50.00
# 0.988 0.988
# 2021-05-12, SELL CREATE, 50.00
# 2021-05-13, SELL EXECUTED, Price: 49.80, Cost: 501.00, Comm 0.50
# 2021-05-13, OPERATION PROFIT, GROSS -3.00, NET -4.00
# 2021-05-13, Close, 50.60
# 0.988 0.988
# 2021-05-13, BUY CREATE, 50.60
# 2021-05-17, BUY EXECUTED, Price: 50.60, Cost: 506.00, Comm 0.51
# 2021-05-17, Close, 51.90
# 0.988 0.988
# 2021-05-17, SELL CREATE, 51.90
# 2021-05-18, SELL EXECUTED, Price: 52.20, Cost: 506.00, Comm 0.52
# 2021-05-18, OPERATION PROFIT, GROSS 16.00, NET 14.97
# 2021-05-18, Close, 52.20
# 0.988 0.988
# 2021-05-18, BUY CREATE, 52.20
# 2021-05-19, BUY EXECUTED, Price: 52.20, Cost: 522.00, Comm 0.52
# 2021-05-19, Close, 52.70
# 0.988 0.988
# 2021-05-19, SELL CREATE, 52.70
# 2021-05-20, SELL EXECUTED, Price: 52.90, Cost: 522.00, Comm 0.53
# 2021-05-20, OPERATION PROFIT, GROSS 7.00, NET 5.95
# 2021-05-20, Close, 52.50
# 0.988 0.988
# 2021-05-20, BUY CREATE, 52.50
# 2021-05-21, BUY EXECUTED, Price: 52.70, Cost: 527.00, Comm 0.53
# 2021-05-21, Close, 52.30
# 0.988 0.988
# 2021-05-21, SELL CREATE, 52.30
# 2021-05-24, SELL EXECUTED, Price: 52.00, Cost: 527.00, Comm 0.52
# 2021-05-24, OPERATION PROFIT, GROSS -7.00, NET -8.05
# 2021-05-24, Close, 52.80
# 0.988 0.988
# 2021-05-24, BUY CREATE, 52.80
# 2021-05-25, BUY EXECUTED, Price: 52.80, Cost: 528.00, Comm 0.53
# 2021-05-25, Close, 54.70
# 0.988 0.988
# 2021-05-25, SELL CREATE, 54.70
# 2021-05-28, SELL EXECUTED, Price: 54.80, Cost: 528.00, Comm 0.55
# 2021-05-28, OPERATION PROFIT, GROSS 20.00, NET 18.92
# 2021-05-28, Close, 55.90
# 0.988 0.988
# 2021-05-28, BUY CREATE, 55.90
# 2021-05-31, BUY EXECUTED, Price: 56.00, Cost: 560.00, Comm 0.56
# 2021-05-31, Close, 55.60
# 0.988 0.988
# 2021-05-31, SELL CREATE, 55.60
# 2021-06-01, SELL EXECUTED, Price: 55.60, Cost: 560.00, Comm 0.56
# 2021-06-01, OPERATION PROFIT, GROSS -4.00, NET -5.12
# 2021-06-01, Close, 55.90
# 0.979 0.988
# 2021-06-01, BUY CREATE, 55.90
# 2021-06-02, BUY EXECUTED, Price: 55.90, Cost: 559.00, Comm 0.56
# 2021-06-02, Close, 55.80
# 0.979 0.979
# 2021-06-02, SELL CREATE, 55.80
# 2021-06-03, SELL EXECUTED, Price: 55.90, Cost: 559.00, Comm 0.56
# 2021-06-03, OPERATION PROFIT, GROSS 0.00, NET -1.12
# 2021-06-03, Close, 56.00
# 0.979 0.979
# 2021-06-03, BUY CREATE, 56.00
# 2021-06-04, BUY EXECUTED, Price: 55.00, Cost: 550.00, Comm 0.55
# 2021-06-04, Close, 55.70
# 0.979 0.979
# 2021-06-04, SELL CREATE, 55.70
# 2021-06-07, SELL EXECUTED, Price: 55.80, Cost: 550.00, Comm 0.56
# 2021-06-07, OPERATION PROFIT, GROSS 8.00, NET 6.89
# 2021-06-07, Close, 55.30
# 0.979 0.979
# 2021-06-07, BUY CREATE, 55.30
# 2021-06-08, BUY EXECUTED, Price: 55.30, Cost: 553.00, Comm 0.55
# 2021-06-08, Close, 54.90
# 0.979 0.979
# 2021-06-08, SELL CREATE, 54.90
# 2021-06-09, SELL EXECUTED, Price: 55.00, Cost: 553.00, Comm 0.55
# 2021-06-09, OPERATION PROFIT, GROSS -3.00, NET -4.10
# 2021-06-09, Close, 55.00
# 0.979 0.979
# 2021-06-09, BUY CREATE, 55.00
# 2021-06-10, BUY EXECUTED, Price: 55.00, Cost: 550.00, Comm 0.55
# 2021-06-10, Close, 55.10
# 0.979 0.979
# 2021-06-10, SELL CREATE, 55.10
# 2021-06-11, SELL EXECUTED, Price: 55.90, Cost: 550.00, Comm 0.56
# 2021-06-11, OPERATION PROFIT, GROSS 9.00, NET 7.89
# 2021-06-11, Close, 55.50
# 0.979 0.979
# 2021-06-11, BUY CREATE, 55.50
# 2021-06-14, BUY EXECUTED, Price: 55.10, Cost: 551.00, Comm 0.55
# 2021-06-14, Close, 55.80
# 0.979 0.979
# 2021-06-14, SELL CREATE, 55.80
# 2021-06-15, SELL EXECUTED, Price: 55.80, Cost: 551.00, Comm 0.56
# 2021-06-15, OPERATION PROFIT, GROSS 7.00, NET 5.89
# 2021-06-15, Close, 55.30
# 0.979 0.979
# 2021-06-15, BUY CREATE, 55.30
# 2021-06-16, BUY EXECUTED, Price: 55.00, Cost: 550.00, Comm 0.55
# 2021-06-16, Close, 55.10
# 0.979 0.979
# 2021-06-16, SELL CREATE, 55.10
# 2021-06-17, SELL EXECUTED, Price: 55.30, Cost: 550.00, Comm 0.55
# 2021-06-17, OPERATION PROFIT, GROSS 3.00, NET 1.90
# 2021-06-17, Close, 55.20
# 0.979 0.979
# 2021-06-17, BUY CREATE, 55.20
# 2021-06-18, BUY EXECUTED, Price: 55.20, Cost: 552.00, Comm 0.55
# 2021-06-18, Close, 55.30
# 0.979 0.979
# 2021-06-18, SELL CREATE, 55.30
# 2021-06-21, SELL EXECUTED, Price: 55.20, Cost: 552.00, Comm 0.55
# 2021-06-21, OPERATION PROFIT, GROSS 0.00, NET -1.10
# 2021-06-21, Close, 55.20
# 0.979 0.979
# 2021-06-21, BUY CREATE, 55.20
# 2021-06-22, BUY EXECUTED, Price: 55.00, Cost: 550.00, Comm 0.55
# 2021-06-22, Close, 54.60
# 0.979 0.979
# 2021-06-22, SELL CREATE, 54.60
# 2021-06-23, SELL EXECUTED, Price: 54.50, Cost: 550.00, Comm 0.55
# 2021-06-23, OPERATION PROFIT, GROSS -5.00, NET -6.10
# 2021-06-23, Close, 54.40
# 0.979 0.979
# 2021-06-23, BUY CREATE, 54.40
# 2021-06-25, BUY EXECUTED, Price: 54.30, Cost: 543.00, Comm 0.54
# 2021-06-25, Close, 54.20
# 0.979 0.979
# 2021-06-25, SELL CREATE, 54.20
# 2021-06-28, SELL EXECUTED, Price: 54.20, Cost: 543.00, Comm 0.54
# 2021-06-28, OPERATION PROFIT, GROSS -1.00, NET -2.08
# 2021-06-28, Close, 54.10
# 0.979 0.979
# 2021-06-28, BUY CREATE, 54.10
# 2021-06-29, BUY EXECUTED, Price: 54.00, Cost: 540.00, Comm 0.54
# 2021-06-29, Close, 53.80
# 0.979 0.979
# 2021-06-29, SELL CREATE, 53.80
# 2021-06-30, SELL EXECUTED, Price: 53.50, Cost: 540.00, Comm 0.54
# 2021-06-30, OPERATION PROFIT, GROSS -5.00, NET -6.08
# 2021-06-30, Close, 52.80
# 0.979 0.979
# 2021-06-30, BUY CREATE, 52.80
# 2021-07-01, BUY EXECUTED, Price: 53.00, Cost: 530.00, Comm 0.53
# 2021-07-01, Close, 52.90
# 0.979 0.979
# 2021-07-01, SELL CREATE, 52.90
# 2021-07-02, SELL EXECUTED, Price: 53.00, Cost: 530.00, Comm 0.53
# 2021-07-02, OPERATION PROFIT, GROSS 0.00, NET -1.06
# 2021-07-02, Close, 52.50
# 0.979 0.979
# 2021-07-02, BUY CREATE, 52.50
# 2021-07-05, BUY EXECUTED, Price: 52.40, Cost: 524.00, Comm 0.52
# 2021-07-05, Close, 52.40
# 0.979 0.979
# 2021-07-05, SELL CREATE, 52.40
# 2021-07-06, SELL EXECUTED, Price: 52.40, Cost: 524.00, Comm 0.52
# 2021-07-06, OPERATION PROFIT, GROSS 0.00, NET -1.05
# 2021-07-06, Close, 52.20
# 0.979 0.979
# 2021-07-06, BUY CREATE, 52.20
# 2021-07-07, BUY EXECUTED, Price: 52.40, Cost: 524.00, Comm 0.52
# 2021-07-07, Close, 52.30
# 0.979 0.979
# 2021-07-07, SELL CREATE, 52.30
# 2021-07-08, SELL EXECUTED, Price: 52.50, Cost: 524.00, Comm 0.53
# 2021-07-08, OPERATION PROFIT, GROSS 1.00, NET -0.05
# 2021-07-08, Close, 52.80
# 0.979 0.979
# 2021-07-08, BUY CREATE, 52.80
# 2021-07-09, BUY EXECUTED, Price: 53.00, Cost: 530.00, Comm 0.53
# 2021-07-09, Close, 52.60
# 0.979 0.979
# 2021-07-09, SELL CREATE, 52.60
# 2021-07-12, SELL EXECUTED, Price: 53.00, Cost: 530.00, Comm 0.53
# 2021-07-12, OPERATION PROFIT, GROSS 0.00, NET -1.06
# 2021-07-12, Close, 52.50
# 0.979 0.979
# 2021-07-12, BUY CREATE, 52.50
# 2021-07-13, BUY EXECUTED, Price: 52.50, Cost: 525.00, Comm 0.53
# 2021-07-13, Close, 52.70
# 1.0 0.979
# 2021-07-13, SELL CREATE, 52.70
# 2021-07-14, SELL EXECUTED, Price: 52.50, Cost: 525.00, Comm 0.53
# 2021-07-14, OPERATION PROFIT, GROSS 0.00, NET -1.05
# 2021-07-14, Close, 53.00
# 1.0 1.0
# 2021-07-14, BUY CREATE, 53.00
# 2021-07-15, BUY EXECUTED, Price: 53.30, Cost: 533.00, Comm 0.53
# 2021-07-15, Close, 53.10
# 1.0 1.0
# 2021-07-15, SELL CREATE, 53.10
# 2021-07-16, SELL EXECUTED, Price: 53.20, Cost: 533.00, Comm 0.53
# 2021-07-16, OPERATION PROFIT, GROSS -1.00, NET -2.06
# 2021-07-16, Close, 53.30
# 1.0 1.0
# 2021-07-16, BUY CREATE, 53.30
# 2021-07-19, BUY EXECUTED, Price: 53.00, Cost: 530.00, Comm 0.53
# 2021-07-19, Close, 53.40
# 1.0 1.0
# 2021-07-19, SELL CREATE, 53.40
# 2021-07-20, SELL EXECUTED, Price: 53.50, Cost: 530.00, Comm 0.54
# 2021-07-20, OPERATION PROFIT, GROSS 5.00, NET 3.94
# 2021-07-20, Close, 52.80
# 0.907 1.0
# 2021-07-20, BUY CREATE, 52.80
# 2021-07-22, BUY EXECUTED, Price: 52.60, Cost: 526.00, Comm 0.53
# 2021-07-22, Close, 52.00
# 0.907 0.907
# 2021-07-22, SELL CREATE, 52.00
# 2021-07-26, SELL EXECUTED, Price: 52.00, Cost: 526.00, Comm 0.52
# 2021-07-26, OPERATION PROFIT, GROSS -6.00, NET -7.05
# 2021-07-26, Close, 51.40
# 0.907 0.907
# 2021-07-26, BUY CREATE, 51.40
# 2021-07-27, BUY EXECUTED, Price: 51.50, Cost: 515.00, Comm 0.52
# 2021-07-27, Close, 51.50
# 0.907 0.907
# 2021-07-27, SELL CREATE, 51.50
# 2021-07-28, SELL EXECUTED, Price: 51.70, Cost: 515.00, Comm 0.52
# 2021-07-28, OPERATION PROFIT, GROSS 2.00, NET 0.97
# 2021-07-28, Close, 51.60
# 0.907 0.907
# 2021-07-28, BUY CREATE, 51.60
# 2021-07-29, BUY EXECUTED, Price: 51.80, Cost: 518.00, Comm 0.52
# 2021-07-29, Close, 51.80
# 0.99 0.907
# 2021-07-29, SELL CREATE, 51.80
# 2021-07-30, SELL EXECUTED, Price: 51.80, Cost: 518.00, Comm 0.52
# 2021-07-30, OPERATION PROFIT, GROSS 0.00, NET -1.04
# 2021-07-30, Close, 51.70
# 0.766 0.99
# 2021-07-30, BUY CREATE, 51.70
# 2021-08-02, BUY EXECUTED, Price: 52.00, Cost: 520.00, Comm 0.52
# 2021-08-02, Close, 51.10
# 0.766 0.766
# 2021-08-02, SELL CREATE, 51.10
# 2021-08-03, SELL EXECUTED, Price: 51.00, Cost: 520.00, Comm 0.51
# 2021-08-03, OPERATION PROFIT, GROSS -10.00, NET -11.03
# 2021-08-03, Close, 51.00
# 0.766 0.766
# 2021-08-03, BUY CREATE, 51.00
# 2021-08-04, BUY EXECUTED, Price: 51.00, Cost: 510.00, Comm 0.51
# 2021-08-04, Close, 51.00
# 0.766 0.766
# 2021-08-04, SELL CREATE, 51.00
# 2021-08-05, SELL EXECUTED, Price: 50.90, Cost: 510.00, Comm 0.51
# 2021-08-05, OPERATION PROFIT, GROSS -1.00, NET -2.02
# 2021-08-05, Close, 50.60
# 0.766 0.766
# 2021-08-05, BUY CREATE, 50.60
# 2021-08-06, BUY EXECUTED, Price: 50.70, Cost: 507.00, Comm 0.51
# 2021-08-06, Close, 50.70
# 0.766 0.766
# 2021-08-06, SELL CREATE, 50.70
# 2021-08-09, SELL EXECUTED, Price: 50.70, Cost: 507.00, Comm 0.51
# 2021-08-09, OPERATION PROFIT, GROSS 0.00, NET -1.01
# 2021-08-09, Close, 50.50
# 0.766 0.766
# 2021-08-09, BUY CREATE, 50.50
# 2021-08-10, BUY EXECUTED, Price: 50.50, Cost: 505.00, Comm 0.51
# 2021-08-10, Close, 50.00
# 0.766 0.766
# 2021-08-10, SELL CREATE, 50.00
# 2021-08-11, SELL EXECUTED, Price: 50.00, Cost: 505.00, Comm 0.50
# 2021-08-11, OPERATION PROFIT, GROSS -5.00, NET -6.00
# 2021-08-11, Close, 50.30
# 0.766 0.766
# 2021-08-11, BUY CREATE, 50.30
# 2021-08-12, BUY EXECUTED, Price: 50.20, Cost: 502.00, Comm 0.50
# 2021-08-12, Close, 50.10
# 0.766 0.766
# 2021-08-12, SELL CREATE, 50.10
# 2021-08-13, SELL EXECUTED, Price: 50.50, Cost: 502.00, Comm 0.51
# 2021-08-13, OPERATION PROFIT, GROSS 3.00, NET 1.99
# 2021-08-13, Close, 50.50
# 0.766 0.766
# 2021-08-13, BUY CREATE, 50.50
# 2021-08-16, BUY EXECUTED, Price: 50.50, Cost: 505.00, Comm 0.51
# 2021-08-16, Close, 50.40
# 0.766 0.766
# 2021-08-16, SELL CREATE, 50.40
# 2021-08-17, SELL EXECUTED, Price: 50.50, Cost: 505.00, Comm 0.51
# 2021-08-17, OPERATION PROFIT, GROSS 0.00, NET -1.01
# 2021-08-17, Close, 50.60
# 0.766 0.766
# 2021-08-17, BUY CREATE, 50.60
# 2021-08-18, BUY EXECUTED, Price: 50.80, Cost: 508.00, Comm 0.51
# 2021-08-18, Close, 50.20
# 0.766 0.766
# 2021-08-18, SELL CREATE, 50.20
# 2021-08-19, SELL EXECUTED, Price: 50.20, Cost: 508.00, Comm 0.50
# 2021-08-19, OPERATION PROFIT, GROSS -6.00, NET -7.01
# 2021-08-19, Close, 50.50
# 0.766 0.766
# 2021-08-19, BUY CREATE, 50.50
# 2021-08-20, BUY EXECUTED, Price: 50.50, Cost: 505.00, Comm 0.51
# 2021-08-20, Close, 50.60
# 0.766 0.766
# 2021-08-20, SELL CREATE, 50.60
# 2021-08-23, SELL EXECUTED, Price: 50.60, Cost: 505.00, Comm 0.51
# 2021-08-23, OPERATION PROFIT, GROSS 1.00, NET -0.01
# 2021-08-23, Close, 50.20
# 0.766 0.766
# 2021-08-23, BUY CREATE, 50.20
# 2021-08-24, BUY EXECUTED, Price: 50.20, Cost: 502.00, Comm 0.50
# 2021-08-24, Close, 51.10
# 0.766 0.766
# 2021-08-24, SELL CREATE, 51.10
# 2021-08-25, SELL EXECUTED, Price: 51.20, Cost: 502.00, Comm 0.51
# 2021-08-25, OPERATION PROFIT, GROSS 10.00, NET 8.99
# 2021-08-25, Close, 51.00
# 0.766 0.766
# 2021-08-25, BUY CREATE, 51.00
# 2021-08-26, BUY EXECUTED, Price: 51.00, Cost: 510.00, Comm 0.51
# 2021-08-26, Close, 53.70
# 0.766 0.766
# 2021-08-26, SELL CREATE, 53.70
# 2021-08-27, SELL EXECUTED, Price: 55.00, Cost: 510.00, Comm 0.55
# 2021-08-27, OPERATION PROFIT, GROSS 40.00, NET 38.94
# 2021-08-27, Close, 52.60
# 0.766 0.766
# 2021-08-27, BUY CREATE, 52.60
# 2021-08-30, BUY EXECUTED, Price: 52.60, Cost: 526.00, Comm 0.53
# 2021-08-30, Close, 51.50
# 0.766 0.766
# 2021-08-30, SELL CREATE, 51.50
# 2021-08-31, SELL EXECUTED, Price: 51.50, Cost: 526.00, Comm 0.52
# 2021-08-31, OPERATION PROFIT, GROSS -11.00, NET -12.04
# 2021-08-31, Close, 52.90
# 0.766 0.766
# 2021-08-31, BUY CREATE, 52.90
# 2021-09-01, BUY EXECUTED, Price: 52.10, Cost: 521.00, Comm 0.52
# 2021-09-01, Close, 51.90
# 0.766 0.766
# 2021-09-01, SELL CREATE, 51.90
# 2021-09-02, SELL EXECUTED, Price: 52.00, Cost: 521.00, Comm 0.52
# 2021-09-02, OPERATION PROFIT, GROSS -1.00, NET -2.04
# 2021-09-02, Close, 52.90
# 0.766 0.766
# 2021-09-02, BUY CREATE, 52.90
# 2021-09-03, BUY EXECUTED, Price: 53.00, Cost: 530.00, Comm 0.53
# 2021-09-03, Close, 52.20
# 0.766 0.766
# 2021-09-03, SELL CREATE, 52.20
# 2021-09-06, SELL EXECUTED, Price: 51.90, Cost: 530.00, Comm 0.52
# 2021-09-06, OPERATION PROFIT, GROSS -11.00, NET -12.05
# 2021-09-06, Close, 52.00
# 0.766 0.766
# 2021-09-06, BUY CREATE, 52.00
# 2021-09-06, (MA Period  8) Ending Value 100007.66
# Final Portfolio Value: 100007.66
# <img src="data:image/png;base64,..." width="431.66664951377516">
